# %% [markdown]
# ### Pandas
#
# Importe o pacote `pandas`. Chame-o de `pd`.

# %%
import pandas as pd

# %% [markdown]
# ## Milionários
#
# O link abaixo contém um csv com dados sobre milionários.
#
# 1. Importe o csv como um dataframe chamado `milionarios`. Quantas linhas e colunas tem esse dataframe?

# %%
url = 'https://corgis-edu.github.io/corgis/datasets/csv/billionaires/billionaires.csv'

# %%
milionarios = pd.read_csv(url)

# %%
df = pd.DataFrame(milionarios)
print(df.shape)
# Out:
# (2614, 22)

# %% [markdown]
# 2. Mostre seus primeiros 5 elementos.

# %%
print(df.head(5))
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# 0                male  ...  8.100000e+12   North America  founder non-finance
# 1                male  ...  1.060000e+13   North America  founder non-finance
# 2                male  ...  0.000000e+00   North America  founder non-finance
# 3                male  ...  8.100000e+12   North America  founder non-finance
# 4                male  ...  1.060000e+13   North America  founder non-finance
#
#   wealth.worth in billions wealth.how.category  wealth.how.from emerging  \
# 0                     18.5         New Sectors                      True
# 1                     58.7         New Sectors                      True
# 2                     76.0         New Sectors                      True
# 3                     15.0      Traded Sectors                      True
# 4                     32.3      Traded Sectors                      True
#
#    wealth.how.industry  wealth.how.inherited wealth.how.was founder  \
# 0  Technology-Computer         not inherited                   True
# 1  Technology-Computer         not inherited                   True
# 2  Technology-Computer         not inherited                   True
# 3             Consumer         not inherited                   True
# 4             Consumer         not inherited                   True
#
#   wealth.how.was political
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# 2. Mostre 5 linhas aleatórias do dataframe

# %%
df.sample(5)
# Out:
#                             name  rank  year  company.founded  \
# 1019                John Sobrato   336  2001             1979
# 832   Mary Alice Dorrance Malone   272  2001             1869
# 1030             Roberto Marinho   336  2001             1925
# 359           Von Siemens family   119  1996             1847
# 1824                 Zhou Hongyi   828  2014             2005
#
#               company.name company.relationship         company.sector  \
# 1019  Sobrato Organization              founder            real estate
# 832          Campbell Soup             relation                   soup
# 1030   Globo Organizations             relation                  media
# 359                Siemens                  NaN  industrial automation
# 1824                 Qihoo              founder     internet companies
#
#      company.type  demographics.age demographics.gender  ...  location.gdp  \
# 1019          new                61                male  ...  1.060000e+13
# 832       aquired                51              female  ...  1.060000e+13
# 1030          new                 0                male  ...  5.600000e+11
# 359           new                 0                 NaN  ...  2.500000e+12
# 1824          new                43                male  ...  0.000000e+00
#
#      location.region          wealth.type wealth.worth in billions  \
# 1019   North America    self-made finance                      1.5
# 832    North America            inherited                      1.8
# 1030   Latin America            inherited                      1.5
# 359           Europe            inherited                      2.6
# 1824       East Asia  founder non-finance                      2.1
#
#      wealth.how.category  wealth.how.from emerging      wealth.how.industry  \
# 1019           Financial                      True              Real Estate
# 832       Traded Sectors                      True                 Consumer
# 1030  Non-Traded Sectors                      True                    Media
# 359       Traded Sectors                      True  Non-consumer industrial
# 1824         New Sectors                      True      Technology-Computer
#
#       wealth.how.inherited wealth.how.was founder wealth.how.was political
# 1019         not inherited                   True                     True
# 832         3rd generation                   True                     True
# 1030                father                   True                     True
# 359          not inherited                   True                     True
# 1824         not inherited                   True                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# 3. Mostre um dataframe contendo apenas os dados do Bill Gates.

# %%
filtro = df.loc[df['name'] == 'Bill Gates']
print(filtro)
# Out:
#          name  rank  year  company.founded company.name company.relationship  \
# 0  Bill Gates     1  1996             1975    Microsoft              founder
# 1  Bill Gates     1  2001             1975    Microsoft              founder
# 2  Bill Gates     1  2014             1975    Microsoft              founder
#
#   company.sector company.type  demographics.age demographics.gender  ...  \
# 0       Software          new                40                male  ...
# 1       Software          new                45                male  ...
# 2       Software          new                58                male  ...
#
#    location.gdp location.region          wealth.type wealth.worth in billions  \
# 0  8.100000e+12   North America  founder non-finance                     18.5
# 1  1.060000e+13   North America  founder non-finance                     58.7
# 2  0.000000e+00   North America  founder non-finance                     76.0
#
#   wealth.how.category  wealth.how.from emerging  wealth.how.industry  \
# 0         New Sectors                      True  Technology-Computer
# 1         New Sectors                      True  Technology-Computer
# 2         New Sectors                      True  Technology-Computer
#
#    wealth.how.inherited wealth.how.was founder wealth.how.was political
# 0         not inherited                   True                     True
# 1         not inherited                   True                     True
# 2         not inherited                   True                     True
#
# [3 rows x 22 columns]

# %% [markdown]
# 4. Qual é o ano mais recente da base? Crie um dataframe chamado `milionarios_2014` onde você filtra apenas as linhas referentes àquele ano. Mostre as 5 primeiras linhas desse dataframe.
#
# Nós usaremos este dataframe daqui para frente.

# %%
milionarios_2014 = df.loc[df['year']==2014]
print(milionarios_2014)
# Out:
#                   name  rank  year  company.founded  \
# 2           Bill Gates     1  2014             1975
# 5     Carlos Slim Helu     2  2014             1990
# 8       Amancio Ortega     3  2014             1975
# 11      Warren Buffett     4  2014             1839
# 14       Larry Ellison     5  2014             1977
# ...                ...   ...   ...              ...
# 2609       Wu Chung-Yi  1565  2014             1991
# 2610          Wu Xiong  1565  2014             1999
# 2611         Yang Keng  1565  2014                0
# 2612     Zdenek Bakala  1565  2014             1994
# 2613       Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 2                           Microsoft              founder
# 5                              Telmex              founder
# 8                                Zara              founder
# 11                 Berkshire Hathaway              founder
# 14                             Oracle              founder
# ...                               ...                  ...
# 2609                           Tingyi             investor
# 2610  Biostime International Holdings                owner
# 2611                    Blue Ray Corp             chairman
# 2612                   Patria Finance              founder
# 2613       Furen Pharmaceutical Group             chairman
#
#           company.sector   company.type  demographics.age demographics.gender  \
# 2               Software            new                58                male
# 5         Communications  privatization                74                male
# 8                Fashion            new                77                male
# 11               Finance        aquired                83                male
# 14              software            new                69                male
# ...                  ...            ...               ...                 ...
# 2609  beverages and food            new                55                male
# 2610      infant formula            new                 0                male
# 2611         real estate            new                53                male
# 2612                coal            new                53                male
# 2613     pharmaceuticals            new                48                male
#
#       ... location.gdp location.region               wealth.type  \
# 2     ...          0.0   North America       founder non-finance
# 5     ...          0.0   Latin America  privatized and resources
# 8     ...          0.0          Europe       founder non-finance
# 11    ...          0.0   North America       founder non-finance
# 14    ...          0.0   North America       founder non-finance
# ...   ...          ...             ...                       ...
# 2609  ...          0.0       East Asia                 executive
# 2610  ...          0.0       East Asia                 executive
# 2611  ...          0.0       East Asia         self-made finance
# 2612  ...          0.0          Europe  privatized and resources
# 2613  ...          0.0       East Asia                 executive
#
#      wealth.worth in billions wealth.how.category  wealth.how.from emerging  \
# 2                        76.0         New Sectors                      True
# 5                        72.0  Non-Traded Sectors                      True
# 8                        64.0  Non-Traded Sectors                      True
# 11                       58.2      Traded Sectors                      True
# 14                       48.0         New Sectors                      True
# ...                       ...                 ...                       ...
# 2609                      1.0      Traded Sectors                      True
# 2610                      1.0      Traded Sectors                      True
# 2611                      1.0           Financial                      True
# 2612                      1.0    Resource Related                      True
# 2613                      1.0         New Sectors                      True
#
#           wealth.how.industry  wealth.how.inherited wealth.how.was founder  \
# 2         Technology-Computer         not inherited                   True
# 5                       Media         not inherited                   True
# 8          Retail, Restaurant         not inherited                   True
# 11                   Consumer         not inherited                   True
# 14        Technology-Computer         not inherited                   True
# ...                       ...                   ...                    ...
# 2609  Non-consumer industrial         not inherited                   True
# 2610                 Consumer         not inherited                   True
# 2611              Real Estate         not inherited                   True
# 2612        Mining and metals         not inherited                   True
# 2613       Technology-Medical         not inherited                   True
#
#      wealth.how.was political
# 2                        True
# 5                        True
# 8                        True
# 11                       True
# 14                       True
# ...                       ...
# 2609                     True
# 2610                     True
# 2611                     True
# 2612                     True
# 2613                     True
#
# [1653 rows x 22 columns]

# %%
print(milionarios_2014.head(5))
# Out:
#                 name  rank  year  company.founded        company.name  \
# 2         Bill Gates     1  2014             1975           Microsoft
# 5   Carlos Slim Helu     2  2014             1990              Telmex
# 8     Amancio Ortega     3  2014             1975                Zara
# 11    Warren Buffett     4  2014             1839  Berkshire Hathaway
# 14     Larry Ellison     5  2014             1977              Oracle
#
#    company.relationship   company.sector   company.type  demographics.age  \
# 2               founder         Software            new                58
# 5               founder   Communications  privatization                74
# 8               founder          Fashion            new                77
# 11              founder          Finance        aquired                83
# 14              founder         software            new                69
#
#    demographics.gender  ... location.gdp location.region  \
# 2                 male  ...          0.0   North America
# 5                 male  ...          0.0   Latin America
# 8                 male  ...          0.0          Europe
# 11                male  ...          0.0   North America
# 14                male  ...          0.0   North America
#
#                  wealth.type wealth.worth in billions wealth.how.category  \
# 2        founder non-finance                     76.0         New Sectors
# 5   privatized and resources                     72.0  Non-Traded Sectors
# 8        founder non-finance                     64.0  Non-Traded Sectors
# 11       founder non-finance                     58.2      Traded Sectors
# 14       founder non-finance                     48.0         New Sectors
#
#     wealth.how.from emerging  wealth.how.industry  wealth.how.inherited  \
# 2                       True  Technology-Computer         not inherited
# 5                       True                Media         not inherited
# 8                       True   Retail, Restaurant         not inherited
# 11                      True             Consumer         not inherited
# 14                      True  Technology-Computer         not inherited
#
#    wealth.how.was founder wealth.how.was political
# 2                    True                     True
# 5                    True                     True
# 8                    True                     True
# 11                   True                     True
# 14                   True                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# 5. A coluna `location.citizenship` identifica a cidadania do milionário. Liste os 5 países do mundo com mais milionários e o número de milionários em cada um desses países.

# %%
cidadania = milionarios_2014["location.citizenship"]
cidadania.value_counts(ascending=False).head(5)
# Out:
# United States    499
# China            152
# Russia           111
# Germany           85
# Brazil            65
# Name: location.citizenship, dtype: int64

# %% [markdown]
# ## Covid
#
# Você já deve ter visto o [dashboard](https://coronavirus.jhu.edu/map.html) da universidade de John Hopkins mapeando o coronavirus. Os dados que eles utilizam estão [aqui](https://github.com/CSSEGISandData/COVID-19). Vamos pegar uma das bases de dados que eles utilizam. Esta:

# %%
link_covid = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

# %% [markdown]
# 1. Importe a base de dados como um dataframe chamado `covid`

# %%
covid = pd.read_csv(link_covid)

# %% [markdown]
# 2. Mostre os primeiros 5 elementos desse dataframe

# %%
covid.head(5)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...     7896    7896    7896    7896
# 1        0        0        0        0  ...     3598    3598    3598    3598
# 2        0        0        0        0  ...     6881    6881    6881    6881
# 3        0        0        0        0  ...      165     165     165     165
# 4        0        0        0        0  ...     1933    1933    1933    1933
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0    7896    7896    7896    7896    7896    7896
# 1    3598    3598    3598    3598    3598    3598
# 2    6881    6881    6881    6881    6881    6881
# 3     165     165     165     165     165     165
# 4    1933    1933    1933    1933    1933    1933
#
# [5 rows x 1147 columns]

# %% [markdown]
# 3. Quantos casos o Brasil tinha no dia 7 de Setembro de 2020?
#
# Note que a base de dados é americana. Assim, Brasil se escreve "Brazil" e 7 de Setembro se escreve "9/7/20"

# %%
covid_brasil = covid.loc[covid["Country/Region"] == "Brazil", "9/7/20"].values[0]
print(covid_brasil)
# Out:
# 127070

# %% [markdown]
# ## Spotify
#
# O link a seguir tem uma base da Spotify com dados sobre músicas disponíveis nesse aplicativo.
#
# 1. Importe a base como um dataframe chamado `Spotify`. Mostre as 5 primeiras linhas.

# %%
url = 'https://corgis-edu.github.io/corgis/datasets/csv/music/music.csv'

# %%
Spotify = pd.read_csv(url)

# %%
Spotify.head(5)
# Out:
#    artist.familiarity  artist.hotttnesss           artist.id  artist.latitude  \
# 0            0.581794           0.401998  ARD7TVE1187B99BFB1          0.00000
# 1            0.630630           0.417500  ARMJAGH1187FB546F3         35.14968
# 2            0.487357           0.343428  ARKRRTF1187B9984DA          0.00000
# 3            0.630382           0.454231  AR7G5I41187FB4CE6C          0.00000
# 4            0.651046           0.401724  ARXR32B1187FB57099          0.00000
#
#    artist.location  artist.longitude       artist.name  artist.similar  \
# 0                0           0.00000            Casual             0.0
# 1                0         -90.04892      The Box Tops             0.0
# 2                0           0.00000  Sonora Santanera             0.0
# 3                0           0.00000          Adam Ant             0.0
# 4                0           0.00000               Gob             0.0
#
#      artist.terms  artist.terms_freq  ...  song.mode  song.mode_confidence  \
# 0         hip hop           1.000000  ...          0                 0.636
# 1  blue-eyed soul           1.000000  ...          0                 0.430
# 2           salsa           1.000000  ...          1                 0.565
# 3        pop rock           0.988584  ...          1                 0.749
# 4        pop punk           0.887288  ...          1                 0.371
#
#    song.start_of_fade_out  song.tatums_confidence  song.tatums_start  \
# 0                 218.932                   0.779            0.28519
# 1                 137.915                   0.969            0.20627
# 2                 172.304                   0.482            0.42132
# 3                 217.124                   0.601            0.56254
# 4                 198.699                   1.000            0.13576
#
#    song.tempo  song.time_signature  song.time_signature_confidence  \
# 0      92.198                  4.0                           0.778
# 1     121.274                  4.0                           0.384
# 2     100.070                  1.0                           0.000
# 3     119.293                  4.0                           0.000
# 4     129.738                  4.0                           0.562
#
#    song.title  song.year
# 0           0          0
# 1           0       1969
# 2           0          0
# 3           0       1982
# 4           0       2007
#
# [5 rows x 35 columns]

# %% [markdown]
# 2. Essa base tem quantas linhas e quantas colunas?

# %%
print(f"{len(Spotify.index)} linhas e {len(Spotify.columns)} colunas")
# Out:
# 10000 linhas e 35 colunas

# %% [markdown]
# 3. Quais são as colunas dessa base?

# %%
Spotify.columns
# Out:
# Index(['artist.familiarity', 'artist.hotttnesss', 'artist.id',
#        'artist.latitude', 'artist.location', 'artist.longitude', 'artist.name',
#        'artist.similar', 'artist.terms', 'artist.terms_freq', 'release.id',
#        'release.name', 'song.artist_mbtags', 'song.artist_mbtags_count',
#        'song.bars_confidence', 'song.bars_start', 'song.beats_confidence',
#        'song.beats_start', 'song.duration', 'song.end_of_fade_in',
#        'song.hotttnesss', 'song.id', 'song.key', 'song.key_confidence',
#        'song.loudness', 'song.mode', 'song.mode_confidence',
#        'song.start_of_fade_out', 'song.tatums_confidence', 'song.tatums_start',
#        'song.tempo', 'song.time_signature', 'song.time_signature_confidence',
#        'song.title', 'song.year'],
#       dtype='object')

# %% [markdown]
# 4. Cada linha corresponde a uma música e o identificador dessa música é a variável `song.id`. Transforme essa variável em um índice da base spotify.

# %%
Spotify.set_index('song.id')
# Out:
#                     artist.familiarity  artist.hotttnesss           artist.id  \
# song.id
# SOMZWCG12A8C13C480            0.581794           0.401998  ARD7TVE1187B99BFB1
# SOCIWDW12A8C13D406            0.630630           0.417500  ARMJAGH1187FB546F3
# SOXVLOJ12AB0189215            0.487357           0.343428  ARKRRTF1187B9984DA
# SONHOTT12A8C13493C            0.630382           0.454231  AR7G5I41187FB4CE6C
# SOFSOCN12A8C143F5D            0.651046           0.401724  ARXR32B1187FB57099
# ...                                ...                ...                 ...
# SOLXXPY12A67ADABA0            0.722571           0.499826  AR4C6V01187FB3BAF4
# SOAYONI12A6D4F85C8            0.511663           0.409779  AR9JLBU1187B9AAEC4
# SOJZLAJ12AB017E8A2            0.433508           0.289903  ARS1DCR1187B9A4A56
# SORZSCJ12A8C132446            0.334457           0.216829  ARAGMIV11F4C843F78
# SOFAOMI12A6D4FA2D8            0.609182           0.509243  ARYXOV81187B99831D
#
#                     artist.latitude  artist.location  artist.longitude  \
# song.id
# SOMZWCG12A8C13C480          0.00000                0           0.00000
# SOCIWDW12A8C13D406         35.14968                0         -90.04892
# SOXVLOJ12AB0189215          0.00000                0           0.00000
# SONHOTT12A8C13493C          0.00000                0           0.00000
# SOFSOCN12A8C143F5D          0.00000                0           0.00000
# ...                             ...              ...               ...
# SOLXXPY12A67ADABA0         39.55792                0          -7.84481
# SOAYONI12A6D4F85C8        -33.96243                0          25.62326
# SOJZLAJ12AB017E8A2          0.00000                0           0.00000
# SORZSCJ12A8C132446          0.00000                0           0.00000
# SOFAOMI12A6D4FA2D8          0.00000                0           0.00000
#
#                                  artist.name  artist.similar  \
# song.id
# SOMZWCG12A8C13C480                    Casual             0.0
# SOCIWDW12A8C13D406              The Box Tops             0.0
# SOXVLOJ12AB0189215          Sonora Santanera             0.0
# SONHOTT12A8C13493C                  Adam Ant             0.0
# SOFSOCN12A8C143F5D                       Gob             0.0
# ...                                      ...             ...
# SOLXXPY12A67ADABA0                 Moonspell             0.0
# SOAYONI12A6D4F85C8            Danny Williams             0.0
# SOJZLAJ12AB017E8A2             Winston Reedy             0.0
# SORZSCJ12A8C132446  Myrick "Freeze" Guillory             0.0
# SOFAOMI12A6D4FA2D8       Seventh Day Slumber             0.0
#
#                           artist.terms  artist.terms_freq  ...  song.mode  \
# song.id                                                    ...
# SOMZWCG12A8C13C480             hip hop           1.000000  ...          0
# SOCIWDW12A8C13D406      blue-eyed soul           1.000000  ...          0
# SOXVLOJ12AB0189215               salsa           1.000000  ...          1
# SONHOTT12A8C13493C            pop rock           0.988584  ...          1
# SOFSOCN12A8C143F5D            pop punk           0.887288  ...          1
# ...                                ...                ...  ...        ...
# SOLXXPY12A67ADABA0  sympho black metal           0.999765  ...          1
# SOAYONI12A6D4F85C8              ballad           0.915417  ...          1
# SOJZLAJ12AB017E8A2         lovers rock           0.960115  ...          1
# SORZSCJ12A8C132446              zydeco           1.000000  ...          1
# SOFAOMI12A6D4FA2D8      christian rock           0.926220  ...          0
#
#                     song.mode_confidence  song.start_of_fade_out  \
# song.id
# SOMZWCG12A8C13C480                 0.636                 218.932
# SOCIWDW12A8C13D406                 0.430                 137.915
# SOXVLOJ12AB0189215                 0.565                 172.304
# SONHOTT12A8C13493C                 0.749                 217.124
# SOFSOCN12A8C143F5D                 0.371                 198.699
# ...                                  ...                     ...
# SOLXXPY12A67ADABA0                 0.540                 386.194
# SOAYONI12A6D4F85C8                 0.398                 163.463
# SOJZLAJ12AB017E8A2                 0.565                 186.015
# SORZSCJ12A8C132446                 0.503                 300.826
# SOFAOMI12A6D4FA2D8                 0.406                 193.167
#
#                     song.tatums_confidence  song.tatums_start  song.tempo  \
# song.id
# SOMZWCG12A8C13C480                   0.779            0.28519      92.198
# SOCIWDW12A8C13D406                   0.969            0.20627     121.274
# SOXVLOJ12AB0189215                   0.482            0.42132     100.070
# SONHOTT12A8C13493C                   0.601            0.56254     119.293
# SOFSOCN12A8C143F5D                   1.000            0.13576     129.738
# ...                                    ...                ...         ...
# SOLXXPY12A67ADABA0                   0.224            0.22262     140.185
# SOAYONI12A6D4F85C8                   0.604            0.07692      77.072
# SOJZLAJ12AB017E8A2                   1.000            0.27924     118.123
# SORZSCJ12A8C132446                   0.421            0.28192     137.663
# SOFAOMI12A6D4FA2D8                   0.710            0.20535     150.575
#
#                     song.time_signature  song.time_signature_confidence  \
# song.id
# SOMZWCG12A8C13C480                  4.0                           0.778
# SOCIWDW12A8C13D406                  4.0                           0.384
# SOXVLOJ12AB0189215                  1.0                           0.000
# SONHOTT12A8C13493C                  4.0                           0.000
# SOFSOCN12A8C143F5D                  4.0                           0.562
# ...                                 ...                             ...
# SOLXXPY12A67ADABA0                  4.0                           0.099
# SOAYONI12A6D4F85C8                  3.0                           0.597
# SOJZLAJ12AB017E8A2                  4.0                           0.205
# SORZSCJ12A8C132446                  4.0                           0.000
# SOFAOMI12A6D4FA2D8                  4.0                           0.317
#
#                     song.title  song.year
# song.id
# SOMZWCG12A8C13C480           0          0
# SOCIWDW12A8C13D406           0       1969
# SOXVLOJ12AB0189215           0          0
# SONHOTT12A8C13493C           0       1982
# SOFSOCN12A8C143F5D           0       2007
# ...                        ...        ...
# SOLXXPY12A67ADABA0           0       1998
# SOAYONI12A6D4F85C8           0       1998
# SOJZLAJ12AB017E8A2           0          0
# SORZSCJ12A8C132446           0          0
# SOFAOMI12A6D4FA2D8           0       2005
#
# [10000 rows x 34 columns]

# %% [markdown]
# 5. Crie um dataframe contendo as seguintes colunas:
#     * O nome do artista (`artist.name`)
#     * O ano da música (`song.year`)
#
# Chame esse dataframe de `producao_do_artista`.

# %%
producao_do_artista = pd.concat([Spotify["artist.name"],Spotify["song.year"]],axis=1)
producao_do_artista
# Out:
#                    artist.name  song.year
# 0                       Casual          0
# 1                 The Box Tops       1969
# 2             Sonora Santanera          0
# 3                     Adam Ant       1982
# 4                          Gob       2007
# ...                        ...        ...
# 9995                 Moonspell       1998
# 9996            Danny Williams       1998
# 9997             Winston Reedy          0
# 9998  Myrick "Freeze" Guillory          0
# 9999       Seventh Day Slumber       2005
#
# [10000 rows x 2 columns]

# %% [markdown]
# 6. Quando o ano da autoria da música é desconhecido, ele aparece como zero. Crie um dataframe que contenha apenas as linhas onde o ano da música não é zero. Chame esse dataframe de `producao_do_artista`.

# %%
producao_do_artista = producao_do_artista[producao_do_artista["song.year"]!=0]
producao_do_artista
# Out:
#                artist.name  song.year
# 1             The Box Tops       1969
# 3                 Adam Ant       1982
# 4                      Gob       2007
# 8         Planet P Project       1984
# 14           Lionel Richie       1986
# ...                    ...        ...
# 9991      David Arkenstone       1996
# 9994  Blind Willie Johnson       1989
# 9995             Moonspell       1998
# 9996        Danny Williams       1998
# 9999   Seventh Day Slumber       2005
#
# [4680 rows x 2 columns]

# %% [markdown]
# 7. Use o comando `.groupby` e `.count()` para contar quantas músicas foram compostas em cada ano. Salve isso no dataframe `musicas_por_ano`.

# %%
musicas_por_ano = producao_do_artista.groupby("song.year").count()
musicas_por_ano
# Out:
#            artist.name
# song.year
# 1926                 2
# 1927                 3
# 1929                 1
# 1930                 2
# 1934                 1
# ...                ...
# 2006               320
# 2007               285
# 2008               253
# 2009               250
# 2010                64
#
# [68 rows x 1 columns]

# %% [markdown]
# 8. Mude o nome da coluna de `musicas_por_ano` de `artist.name` para `numero_de_musicas`

# %%
musicas_por_ano.columns=['numero_de_musicas']
musicas_por_ano
# Out:
#            numero_de_musicas
# song.year
# 1926                       2
# 1927                       3
# 1929                       1
# 1930                       2
# 1934                       1
# ...                      ...
# 2006                     320
# 2007                     285
# 2008                     253
# 2009                     250
# 2010                      64
#
# [68 rows x 1 columns]

# %% [markdown]
# Só de brincadeira, rode o comando abaixo e veja o que aparece:

# %%
musicas_por_ano.plot(figsize=(20,6),title='músicas por ano');
