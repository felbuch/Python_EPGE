# %% [markdown]
# Python tem _pacotes_, que são conjuntos de funções feitas por outras pessoas que podemos usar. Por exemplo,

# %%
from math import cos

# %%
cos(0)

# %%
sin(0)

# %%
from math import log10

# %%
log10(100)

# %%
from math import *

# %%
sin(pi/2)

# %%
import math as m
m.tan(pi/4)

# %%
import math

# %%
math.pow?

# %%
math.pow(2,3)

# %%
from numpy import dot

# %%
dot() #shift + tab

# %% [markdown]
# Stack Overflow

# %% [markdown]
# ## Instalando pacotes

# %%
# !pip install investpy
# Out:
# Collecting investpy
#   Downloading investpy-1.0.tar.gz (4.4 MB)
# Collecting Unidecode>=1.1.1
#   Downloading Unidecode-1.1.1-py2.py3-none-any.whl (238 kB)
# Requirement already satisfied: setuptools>=41.2.0 in c:\users\felbu\miniconda3\lib\site-packages (from investpy) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\felbu\miniconda3\lib\site-packages (from investpy) (1.19.2)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\felbu\miniconda3\lib\site-packages (from investpy) (1.1.5)
# Collecting lxml>=4.4.1
#   Downloading lxml-4.6.2-cp38-cp38-win32.whl (3.2 MB)
# Requirement already satisfied: requests>=2.22.0 in c:\users\felbu\miniconda3\lib\site-packages (from investpy) (2.24.0)
# Requirement already satisfied: pytz>=2019.3 in c:\users\felbu\miniconda3\lib\site-packages (from investpy) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\felbu\miniconda3\lib\site-packages (from pandas>=0.25.1->investpy) (2.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\felbu\miniconda3\lib\site-packages (from requests>=2.22.0->investpy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felbu\miniconda3\lib\site-packages (from requests>=2.22.0->investpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\felbu\miniconda3\lib\site-packages (from requests>=2.22.0->investpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\felbu\miniconda3\lib\site-packages (from requests>=2.22.0->investpy) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\felbu\miniconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.15.0)
# Building wheels for collected packages: investpy
#   Building wheel for investpy (setup.py): started
#   Building wheel for investpy (setup.py): finished with status 'done'
#   Created wheel for investpy: filename=investpy-1.0-py3-none-any.whl size=4465845 sha256=389633a0dd6860de499177d0d5be2fa42423ee9263af6023dd35ca1438d5bcef
#   Stored in directory: c:\users\felbu\appdata\local\pip\cache\wheels\6a\1d\35\76f15450b4c9c3f5ba40a5b037281874978b2093da7d482e9b
# Successfully built investpy
# Installing collected packages: Unidecode, lxml, investpy
# Successfully installed Unidecode-1.1.1 investpy-1.0 lxml-4.6.2

# %% [markdown]
# ## Estudo de caso

# %%
import investpy

# %%
dir(investpy)
# Out:
# ['__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'bonds',
#  'certificates',
#  'commodities',
#  'crypto',
#  'currency_crosses',
#  'data',
#  'economic_calendar',
#  'etfs',
#  'funds',
#  'get_available_currencies',
#  'get_bond_countries',
#  'get_bond_historical_data',
#  'get_bond_information',
#  'get_bond_recent_data',
#  'get_bonds',
#  'get_bonds_dict',
#  'get_bonds_list',
#  'get_bonds_overview',
#  'get_certificate_countries',
#  'get_certificate_historical_data',
#  'get_certificate_information',
#  'get_certificate_recent_data',
#  'get_certificates',
#  'get_certificates_dict',
#  'get_certificates_list',
#  'get_certificates_overview',
#  'get_commodities',
#  'get_commodities_dict',
#  'get_commodities_list',
#  'get_commodities_overview',
#  'get_commodity_groups',
#  'get_commodity_historical_data',
#  'get_commodity_information',
#  'get_commodity_recent_data',
#  'get_crypto_historical_data',
#  'get_crypto_information',
#  'get_crypto_recent_data',
#  'get_cryptos',
#  'get_cryptos_dict',
#  'get_cryptos_list',
#  'get_cryptos_overview',
#  'get_currency_cross_historical_data',
#  'get_currency_cross_information',
#  'get_currency_cross_recent_data',
#  'get_currency_crosses',
#  'get_currency_crosses_dict',
#  'get_currency_crosses_list',
#  'get_currency_crosses_overview',
#  'get_etf_countries',
#  'get_etf_historical_data',
#  'get_etf_information',
#  'get_etf_recent_data',
#  'get_etfs',
#  'get_etfs_dict',
#  'get_etfs_list',
#  'get_etfs_overview',
#  'get_fund_countries',
#  'get_fund_historical_data',
#  'get_fund_information',
#  'get_fund_recent_data',
#  'get_funds',
#  'get_funds_dict',
#  'get_funds_list',
#  'get_funds_overview',
#  'get_index_countries',
#  'get_index_historical_data',
#  'get_index_information',
#  'get_index_recent_data',
#  'get_indices',
#  'get_indices_dict',
#  'get_indices_list',
#  'get_indices_overview',
#  'get_stock_company_profile',
#  'get_stock_countries',
#  'get_stock_dividends',
#  'get_stock_financial_summary',
#  'get_stock_historical_data',
#  'get_stock_information',
#  'get_stock_recent_data',
#  'get_stocks',
#  'get_stocks_dict',
#  'get_stocks_list',
#  'get_stocks_overview',
#  'indices',
#  'moving_averages',
#  'news',
#  'pivot_points',
#  'search',
#  'search_bonds',
#  'search_certificates',
#  'search_commodities',
#  'search_cryptos',
#  'search_currency_crosses',
#  'search_etfs',
#  'search_funds',
#  'search_indices',
#  'search_quotes',
#  'search_stocks',
#  'stocks',
#  'technical',
#  'technical_indicators',
#  'utils']

# %%
investpy.get_stock_recent_data?
# Out:
# Signature:
# investpy.get_stock_recent_data(
#     stock,
#     country,
#     as_json=False,
#     order='ascending',
#     interval='Daily',
# )
# Docstring:
# This function retrieves recent historical data from the introduced stock from Investing.com. So on, the recent data
# of the introduced stock from the specified country will be retrieved and returned as a :obj:`pandas.DataFrame` if
# the parameters are valid and the request to Investing.com succeeds. Note that additionally some optional parameters
# can be specified: as_json and order, which let the user decide if the data is going to be returned as a
# :obj:`json` or not, and if the historical data is going to be ordered ascending or descending (where the index is the
# date), respectively.
#
# Args:
#     stock (:obj:`str`): symbol of the stock to retrieve recent historical data from.
#     country (:obj:`str`): name of the country from where the stock is.
#     as_json (:obj:`bool`, optional):
#         to determine the format of the output data, either a :obj:`pandas.DataFrame` if False and a :obj:`json` if True.
#     order (:obj:`str`, optional): to define the order of the retrieved data which can either be ascending or descending.
#     interval (:obj:`str`, optional):
#         value to define the historical data interval to retrieve, by default `Daily`, but it can also be `Weekly` or `Monthly`.
#
# Returns:
#     :obj:`pandas.DataFrame` or :obj:`json`:
#         The function can return either a :obj:`pandas.DataFrame` or a :obj:`json` object, containing the retrieved
#         recent data of the specified stock from the specified country. So on, the resulting dataframe contains the
#         open, high, low, close and volume values for the selected stock on market days and the currency in which those
#         values are presented.
#
#         The resulting recent data, in case that the default parameters were applied, will look like::
#
#             Date || Open | High | Low | Close | Volume | Currency
#             -----||------|------|-----|-------|--------|----------
#             xxxx || xxxx | xxxx | xxx | xxxxx | xxxxxx | xxxxxxxx
#
#         but in case that as_json parameter was defined as True, then the output will be::
#
#             {
#                 name: name,
#                 recent: [
#                     {
#                         date: 'dd/mm/yyyy',
#                         open: x,
#                         high: x,
#                         low: x,
#                         close: x,
#                         volume: x,
#                         currency: x
#                     },
#                     ...
#                 ]
#             }
#
# Raises:
#     ValueError: raised whenever any of the introduced arguments is not valid or errored.
#     IOError: raised if stocks object/file was not found or unable to retrieve.
#     RuntimeError: raised if the introduced stock/country was not found or did not match any of the existing ones.
#     ConnectionError: raised if connection to Investing.com could not be established.
#     IndexError: raised if stock recent data was unavailable or not found in Investing.com.
#
# Examples:
#     >>> data = investpy.get_stock_recent_data(stock='bbva', country='spain')
#     >>> data.head()
#                  Open   High    Low  Close    Volume Currency
#     Date
#     2019-08-13  4.263  4.395  4.230  4.353  27250000      EUR
#     2019-08-14  4.322  4.325  4.215  4.244  36890000      EUR
#     2019-08-15  4.281  4.298  4.187  4.234  21340000      EUR
#     2019-08-16  4.234  4.375  4.208  4.365  46080000      EUR
#     2019-08-19  4.396  4.425  4.269  4.269  18950000      EUR
# File:      c:\users\felbu\miniconda3\lib\site-packages\investpy\stocks.py
# Type:      function

# %%
investpy.get_stock_recent_data('petr4', 'brazil')
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2020-11-19  23.54  23.93  23.38  23.82   63380000      BRL
# 2020-11-20  23.84  23.98  23.47  23.65   36130400      BRL
# 2020-11-23  24.05  25.10  24.04  25.10  125645296      BRL
# 2020-11-24  25.68  26.66  25.65  26.22  153293504      BRL
# 2020-11-25  26.14  26.50  25.67  26.25   73946200      BRL
# 2020-11-26  25.92  25.92  25.57  25.82   41935900      BRL
# 2020-11-27  25.90  26.06  25.48  25.50   49863500      BRL
# 2020-11-30  25.28  25.88  24.85  24.90   90207696      BRL
# 2020-12-01  25.45  25.77  25.30  25.60   58866000      BRL
# 2020-12-02  25.62  26.50  25.33  25.91   88089904      BRL
# 2020-12-03  26.20  26.89  26.08  26.64   62424500      BRL
# 2020-12-04  27.19  27.57  27.07  27.53   61652400      BRL
# 2020-12-07  27.26  27.78  26.68  27.00   72664200      BRL
# 2020-12-08  26.82  27.14  26.47  26.66   46276700      BRL
# 2020-12-09  26.63  26.96  26.44  26.94   52448300      BRL
# 2020-12-10  27.24  28.20  27.14  27.82   97537104      BRL
# 2020-12-11  27.47  27.83  27.29  27.57   48334300      BRL
# 2020-12-14  28.02  28.26  27.62  27.62   49097300      BRL
# 2020-12-15  27.83  27.98  27.65  27.85   47208200      BRL
# 2020-12-16  27.84  28.23  27.50  28.19   59399200      BRL
# 2020-12-17  28.27  28.39  28.08  28.24   39149200      BRL
# 2020-12-18  28.09  28.32  28.02  28.10   44707900      BRL

# %% [markdown]
# ## Um comentário sobre velocidade
#
#
# $$
# \exp(x) = 1 + x + \frac{x^2}{2!} + \frac{x^3}{3!} + ... = \sum_{i=0}^{\infty}\left(\frac{x^i}{i!} \right)
# $$

# %%
def meu_exp(x, n_parcelas = 10):
    
    def fatorial(n):
        if n == 0:
            return(1)
        else:
            return(n * fatorial(n-1))
    
    return(sum([x**i/fatorial(i) for i in range(n_parcelas)]))

# %%
from math import exp # <--- mesma função, mas estou usando um pacote

# %%
# %timeit meu_exp(1) #<-- minha função
# %timeit exp(1)     #<-- função do Python
# Out:
# 9.45 µs ± 65 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 114 ns ± 2.56 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
