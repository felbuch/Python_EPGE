# %% [markdown]
# # Cria base de dados para exemplo

# %% [markdown]
# * Uma observação para cada segundo entre 1-Jan-2021 até 28-Fev-2021.
# * Um arquivo CSV para cada dia do mês (31 para Janeiro + 28 para Fevereiro = 59 no total)
# * Colunas: _Timestamp_ + 5 colunas numéricas aleatórias + 1 coluna categórica

# %%
import pandas as pd
import numpy as np

dates = pd.date_range(start="1-1-2021", end="2-28-2021")

for dt in dates:
    ind_day = pd.date_range(start="%s 0:0:0"%dt.date(), end="%s 23:59:59"%dt.date(), freq="S")
    data = np.random.rand(len(ind_day), 5)

    cls = np.random.choice(["Class1", "Class2", "Class3", "Class4","Class5"], size=len(ind_day))

    df = pd.DataFrame(data=data, columns=["A", "B", "C", "D", "E"], index=ind_day)
    df["Type"] = cls

    df.to_csv("dask_dataframes/%s.csv"%dt.date())

# %%
import os
os.listdir("dask_dataframes/")
# Out:
# ['2021-01-01.csv',
#  '2021-01-02.csv',
#  '2021-01-03.csv',
#  '2021-01-04.csv',
#  '2021-01-05.csv',
#  '2021-01-06.csv',
#  '2021-01-07.csv',
#  '2021-01-08.csv',
#  '2021-01-09.csv',
#  '2021-01-10.csv',
#  '2021-01-11.csv',
#  '2021-01-12.csv',
#  '2021-01-13.csv',
#  '2021-01-14.csv',
#  '2021-01-15.csv',
#  '2021-01-16.csv',
#  '2021-01-17.csv',
#  '2021-01-18.csv',
#  '2021-01-19.csv',
#  '2021-01-20.csv',
#  '2021-01-21.csv',
#  '2021-01-22.csv',
#  '2021-01-23.csv',
#  '2021-01-24.csv',
#  '2021-01-25.csv',
#  '2021-01-26.csv',
#  '2021-01-27.csv',
#  '2021-01-28.csv',
#  '2021-01-29.csv',
#  '2021-01-30.csv',
#  '2021-01-31.csv',
#  '2021-02-01.csv',
#  '2021-02-02.csv',
#  '2021-02-03.csv',
#  '2021-02-04.csv',
#  '2021-02-05.csv',
#  '2021-02-06.csv',
#  '2021-02-07.csv',
#  '2021-02-08.csv',
#  '2021-02-09.csv',
#  '2021-02-10.csv',
#  '2021-02-11.csv',
#  '2021-02-12.csv',
#  '2021-02-13.csv',
#  '2021-02-14.csv',
#  '2021-02-15.csv',
#  '2021-02-16.csv',
#  '2021-02-17.csv',
#  '2021-02-18.csv',
#  '2021-02-19.csv',
#  '2021-02-20.csv',
#  '2021-02-21.csv',
#  '2021-02-22.csv',
#  '2021-02-23.csv',
#  '2021-02-24.csv',
#  '2021-02-25.csv',
#  '2021-02-26.csv',
#  '2021-02-27.csv',
#  '2021-02-28.csv']

# %% [markdown]
# # Cria cluster do dask

# %%
from dask.distributed import Client

client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GB")
client
# Out:
# C:\Users\felbu\anaconda3\lib\site-packages\distributed\node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 49168 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:49169' processes=2 threads=4, memory=1.86 GiB>

# %% [markdown]
# # Lê base de dados

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('dask_dataframes/2021-*-*.csv')

# %%
df.head()
# Out:
#             Unnamed: 0         A         B         C         D         E  \
# 0  2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 1  2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2  2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 3  2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 4  2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#      Type
# 0  Class3
# 1  Class5
# 2  Class2
# 3  Class2
# 4  Class3

# %%
df.tail()
# Out:
#                 Unnamed: 0         A         B         C         D         E  \
# 86395  2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250
# 86396  2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667
# 86397  2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715
# 86398  2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440
# 86399  2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573
#
#          Type
# 86395  Class5
# 86396  Class5
# 86397  Class2
# 86398  Class4
# 86399  Class2

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# A             float64
# B             float64
# C             float64
# D             float64
# E             float64
# Type           object
# dtype: object

# %%
df = df.rename(columns={'Unnamed: 0':'date'}).set_index('date')

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995  Class3
# 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750  Class5
# 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110  Class2
# 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046  Class2
# 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855  Class3

# %%
df.tail()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250  Class5
# 2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667  Class5
# 2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715  Class2
# 2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440  Class4
# 2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573  Class2

# %%
df.dtypes
# Out:
# A       float64
# B       float64
# C       float64
# D       float64
# E       float64
# Type     object
# dtype: object

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'Type'], dtype='object')

# %%
#Não está como datetime!
df.index
# Out:
# Dask Index Structure:
# npartitions=59
# 2021-01-01 00:00:00    object
# 2021-01-02 00:00:00       ...
#                         ...
# 2021-02-28 00:00:00       ...
# 2021-02-28 23:59:59       ...
# Name: date, dtype: object
# Dask Name: sort_index, 295 tasks

# %%
df = dd.read_csv("dask_dataframes/2021-*-*.csv",
                 names=["date", "A", "B", "C", "D", "E", "Type"],
                 skiprows=1,
                 parse_dates=["date",]
                )

# %%
df.head()
# Out:
#                  date         A         B         C         D         E  \
# 0 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 1 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 3 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 4 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#      Type
# 0  Class3
# 1  Class5
# 2  Class2
# 3  Class2
# 4  Class3

# %%
df.dtypes
# Out:
# date    datetime64[ns]
# A              float64
# B              float64
# C              float64
# D              float64
# E              float64
# Type            object
# dtype: object

# %% [markdown]
# # Delayed computation

# %% [markdown]
# ## Exemplo 1

# %%
df['A'].max()
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
df['A'].max().compute()
# Out:
# 0.9999996676628308

# %% [markdown]
# ## Exemplo 2

# %%
df.groupby('Type').mean()
# Out:
# Dask DataFrame Structure:
#                      A        B        C        D        E
# npartitions=1
#                float64  float64  float64  float64  float64
#                    ...      ...      ...      ...      ...
# Dask Name: truediv, 197 tasks

# %%
df.groupby('Type').mean().compute()
# Out:
#                A         B         C         D         E
# Type
# Class1  0.500021  0.500159  0.499956  0.499640  0.499770
# Class2  0.499678  0.499987  0.499696  0.500180  0.499881
# Class3  0.500175  0.499797  0.499966  0.500100  0.499826
# Class4  0.500274  0.499719  0.500275  0.500228  0.500256
# Class5  0.499999  0.500522  0.500138  0.500192  0.500234

# %% [markdown]
# ## Exemplo 3

# %%
df['F'] = df['A'] + df['B']
df['F'] = df['F'] - df['F'].mean()
media = df['F'].mean()
media
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
media.compute()
# Out:
# -1.3143841877348196e-16

# %% [markdown]
# ## Exceções (métodos com compute implícito)

# %%
df.head()
# Out:
#                  date         A         B         C         D         E  \
# 0 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 1 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 3 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 4 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#      Type         F
# 0  Class3  0.189947
# 1  Class5  0.304757
# 2  Class2  0.861750
# 3  Class2 -0.487550
# 4  Class3 -0.461997

# %%
df.tail()
# Out:
#                      date         A         B         C         D         E  \
# 86395 2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250
# 86396 2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667
# 86397 2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715
# 86398 2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440
# 86399 2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573
#
#          Type         F
# 86395  Class5 -0.569572
# 86396  Class5  0.202831
# 86397  Class2  0.325104
# 86398  Class4  0.728631
# 86399  Class2 -0.112771

# %%
#Cuidado
df.sample(frac=1e-5)
# Out:
# Dask DataFrame Structure:
#                           date        A        B        C        D        E    Type        F
# npartitions=59
#                 datetime64[ns]  float64  float64  float64  float64  float64  object  float64
#                            ...      ...      ...      ...      ...      ...     ...      ...
# ...                        ...      ...      ...      ...      ...      ...     ...      ...
#                            ...      ...      ...      ...      ...      ...     ...      ...
# 34602  Class3  0.337066
# 65694  Class2  0.706302
# 42052  Class4  0.198918
# 57637  Class5 -0.148509
# 10705  Class5 -0.485124
# 6488   Class5 -0.072834
# 10621  Class5  0.168378
# 57446  Class3 -0.198151
# 50738  Class4  0.313811
# 60308  Class1 -0.756362
# 39970  Class4  0.756436
# 53891  Class1  0.201454
# 52343  Class1  0.463888
# 49824  Class4 -0.830002
# 18672  Class5  0.993939
# 83953  Class2 -0.403107
# 52988  Class1  0.588110
# 36686  Class2 -0.008589
# 53670  Class2 -0.479921
# 44734  Class3 -0.106665

# %% [markdown]
# # Semelhanças com pandas
#
# A grande vantagem de Dask sobre, por exemplo, Spark

# %% [markdown]
# ## Filtrar linhas

# %%
df_1 = df[df.Type == 'Class1']

# %%
df_1.head()
# Out:
#                   date         A         B         C         D         E  \
# 7  2021-01-01 00:00:07  0.827363  0.478525  0.826150  0.728583  0.134825
# 10 2021-01-01 00:00:10  0.412788  0.630448  0.956777  0.235059  0.896744
# 15 2021-01-01 00:00:15  0.827425  0.857359  0.754480  0.996289  0.672775
# 53 2021-01-01 00:00:53  0.825701  0.899504  0.264561  0.261113  0.267173
# 59 2021-01-01 00:00:59  0.737701  0.734716  0.432248  0.316197  0.834699
#
#       Type         F
# 7   Class1  0.305822
# 10  Class1  0.043170
# 15  Class1  0.684719
# 53  Class1  0.725139
# 59  Class1  0.472350

# %% [markdown]
# ## Selecionar colunas

# %%
df_num = df[['A','B','C','D','E','F']]

# %%
df_num.head()
# Out:
#           A         B         C         D         E         F
# 0  0.771390  0.418623  0.623215  0.401876  0.004995  0.189947
# 1  0.864748  0.440075  0.819741  0.478412  0.866750  0.304757
# 2  0.864099  0.997717  0.568261  0.435532  0.142110  0.861750
# 3  0.266226  0.246290  0.889184  0.231991  0.841046 -0.487550
# 4  0.190853  0.347216  0.480630  0.422721  0.290855 -0.461997

# %% [markdown]
# ## Estatísticas simples

# %%
df.A.mean().compute()
# Out:
# 0.5000292140315263

# %% [markdown]
# ## Group by

# %%
df[['Type','A','B','C']].groupby('Type').agg(['mean','std']).compute()
# Out:
#                A                   B                   C
#             mean       std      mean       std      mean       std
# Type
# Class1  0.500021  0.288660  0.500159  0.288619  0.499956  0.288754
# Class2  0.499678  0.288692  0.499987  0.288781  0.499696  0.288975
# Class3  0.500175  0.288799  0.499797  0.288944  0.499966  0.288800
# Class4  0.500274  0.288835  0.499719  0.288691  0.500275  0.288721
# Class5  0.499999  0.288547  0.500522  0.289014  0.500138  0.288558

# %% [markdown]
# # Resampling

# %%
df_hora = df.resample("1H")

# %%
df_media_hora = df_hora.mean()

# %%
df_media_hora
# Out:
# Dask DataFrame Structure:
#                            A        B        C        D        E        F
# npartitions=59
# 2021-01-01 00:00:00  float64  float64  float64  float64  float64  float64
# 2021-01-02 00:00:00      ...      ...      ...      ...      ...      ...
# ...                      ...      ...      ...      ...      ...      ...
# 2021-02-28 00:00:00      ...      ...      ...      ...      ...      ...
# 2021-02-28 23:00:00      ...      ...      ...      ...      ...      ...
# Dask Name: resample, 889 tasks

# %%
df_media_hora.head()
# Out:
#                             A         B         C         D         E  \
# date
# 2021-01-01 00:00:00  0.502897  0.501565  0.503678  0.497192  0.500488
# 2021-01-01 01:00:00  0.497565  0.495480  0.498473  0.503440  0.500186
# 2021-01-01 02:00:00  0.498016  0.505579  0.502972  0.504882  0.495799
# 2021-01-01 03:00:00  0.498847  0.502555  0.501540  0.497835  0.503687
# 2021-01-01 04:00:00  0.504765  0.487040  0.502415  0.504662  0.501845
#
#                             F
# date
# 2021-01-01 00:00:00  0.004396
# 2021-01-01 01:00:00 -0.007021
# 2021-01-01 02:00:00  0.003529
# 2021-01-01 03:00:00  0.001336
# 2021-01-01 04:00:00 -0.008261

# %% [markdown]
# # Partições

# %%
df.npartitions
# Out:
# 59

# %%
df.partitions[0]
# Out:
# Dask DataFrame Structure:
#                          date        A        B        C        D        E    Type        F
# npartitions=1
#                datetime64[ns]  float64  float64  float64  float64  float64  object  float64
#                           ...      ...      ...      ...      ...      ...     ...      ...
# Dask Name: blocks, 594 tasks

# %%
df.partitions[0].head()
# Out:
#                  date         A         B         C         D         E  \
# 0 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 1 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 3 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 4 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#      Type         F
# 0  Class3  0.189947
# 1  Class5  0.304757
# 2  Class2  0.861750
# 3  Class2 -0.487550
# 4  Class3 -0.461997

# %%
df = df.set_index('date')

# %%
df_hora = df.repartition(freq="1H")

# %%
df_hora.npartitions
# Out:
# 1416

# %%
#Visualmente, não muda nada
df_hora.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995  Class3
# 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750  Class5
# 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110  Class2
# 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046  Class2
# 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855  Class3
#
#                             F
# date
# 2021-01-01 00:00:00  0.189947
# 2021-01-01 00:00:01  0.304757
# 2021-01-01 00:00:02  0.861750
# 2021-01-01 00:00:03 -0.487550
# 2021-01-01 00:00:04 -0.461997

# %%
df_semana = df.repartition(freq='7D')
df_semana.npartitions
# Out:
# 9

# %%
#Aplicar uma função a cada partição
df_semana.manpartitionsartitions(lambda x: x.A.mean())
# Out:
# Dask Series Structure:
# npartitions=59
# 2021-01-01 00:00:00    float64
# 2021-01-02 00:00:00        ...
#                         ...
# 2021-02-28 00:00:00        ...
# 2021-02-28 23:59:59        ...
# dtype: float64
# Dask Name: lambda, 770 tasks

# %%
df_semana.map_partitions(lambda x: x.A.mean()).compute()
# Out:
# 0    0.499922
# 1    0.499982
# 2    0.500394
# 3    0.499533
# 4    0.500046
# 5    0.499716
# 6    0.500151
# 7    0.500322
# 8    0.500296
# dtype: float64

# %% [markdown]
# # O dashboard do Dask
#
# (mostrar o dashboard)
