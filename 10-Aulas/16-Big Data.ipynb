# %% [markdown]
# # Cria base de dados para exemplo

# %% [markdown]
# * Uma observação para cada segundo entre 1-Jan-2021 até 28-Fev-2021.
# * Um arquivo CSV para cada dia do mês (31 para Janeiro + 28 para Fevereiro = 59 no total)
# * Colunas: _Timestamp_ + 5 colunas numéricas aleatórias + 1 coluna categórica

# %%
import pandas as pd
import numpy as np

dates = pd.date_range(start="1-1-2021", end="2-28-2021")

for dt in dates:
    ind_day = pd.date_range(start="%s 0:0:0"%dt.date(), end="%s 23:59:59"%dt.date(), freq="S")
    data = np.random.rand(len(ind_day), 5)

    cls = np.random.choice(["Class1", "Class2", "Class3", "Class4","Class5"], size=len(ind_day))

    df = pd.DataFrame(data=data, columns=["A", "B", "C", "D", "E"], index=ind_day)
    df["Type"] = cls

    df.to_csv("dask_dataframes/%s.csv"%dt.date())

# %%
import os
os.listdir("dask_dataframes/")
# Out:
# ['2021-01-01.csv',
#  '2021-01-02.csv',
#  '2021-01-03.csv',
#  '2021-01-04.csv',
#  '2021-01-05.csv',
#  '2021-01-06.csv',
#  '2021-01-07.csv',
#  '2021-01-08.csv',
#  '2021-01-09.csv',
#  '2021-01-10.csv',
#  '2021-01-11.csv',
#  '2021-01-12.csv',
#  '2021-01-13.csv',
#  '2021-01-14.csv',
#  '2021-01-15.csv',
#  '2021-01-16.csv',
#  '2021-01-17.csv',
#  '2021-01-18.csv',
#  '2021-01-19.csv',
#  '2021-01-20.csv',
#  '2021-01-21.csv',
#  '2021-01-22.csv',
#  '2021-01-23.csv',
#  '2021-01-24.csv',
#  '2021-01-25.csv',
#  '2021-01-26.csv',
#  '2021-01-27.csv',
#  '2021-01-28.csv',
#  '2021-01-29.csv',
#  '2021-01-30.csv',
#  '2021-01-31.csv',
#  '2021-02-01.csv',
#  '2021-02-02.csv',
#  '2021-02-03.csv',
#  '2021-02-04.csv',
#  '2021-02-05.csv',
#  '2021-02-06.csv',
#  '2021-02-07.csv',
#  '2021-02-08.csv',
#  '2021-02-09.csv',
#  '2021-02-10.csv',
#  '2021-02-11.csv',
#  '2021-02-12.csv',
#  '2021-02-13.csv',
#  '2021-02-14.csv',
#  '2021-02-15.csv',
#  '2021-02-16.csv',
#  '2021-02-17.csv',
#  '2021-02-18.csv',
#  '2021-02-19.csv',
#  '2021-02-20.csv',
#  '2021-02-21.csv',
#  '2021-02-22.csv',
#  '2021-02-23.csv',
#  '2021-02-24.csv',
#  '2021-02-25.csv',
#  '2021-02-26.csv',
#  '2021-02-27.csv',
#  '2021-02-28.csv']

# %% [markdown]
# # Cria cluster do dask

# %%
from dask.distributed import Client

client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GB")
client
# Out:
# C:\Users\felbu\anaconda3\lib\site-packages\distributed\node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 49168 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:49169' processes=2 threads=4, memory=1.86 GiB>

# %% [markdown]
# # Lê base de dados

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('dask_dataframes/2021-*-*.csv')

# %%
df.head()
# Out:
#             Unnamed: 0         A         B         C         D         E  \
# 0  2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 1  2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2  2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 3  2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 4  2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#      Type
# 0  Class3
# 1  Class5
# 2  Class2
# 3  Class2
# 4  Class3

# %%
df.tail()
# Out:
#                 Unnamed: 0         A         B         C         D         E  \
# 86395  2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250
# 86396  2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667
# 86397  2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715
# 86398  2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440
# 86399  2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573
#
#          Type
# 86395  Class5
# 86396  Class5
# 86397  Class2
# 86398  Class4
# 86399  Class2

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# A             float64
# B             float64
# C             float64
# D             float64
# E             float64
# Type           object
# dtype: object

# %%
df = df.rename(columns={'Unnamed: 0':'date'}).set_index('date')

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995  Class3
# 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750  Class5
# 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110  Class2
# 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046  Class2
# 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855  Class3

# %%
df.tail()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250  Class5
# 2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667  Class5
# 2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715  Class2
# 2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440  Class4
# 2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573  Class2

# %%
df.dtypes
# Out:
# A       float64
# B       float64
# C       float64
# D       float64
# E       float64
# Type     object
# dtype: object

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'Type'], dtype='object')

# %%
df.index
# Out:
# Dask Index Structure:
# npartitions=59
# 2021-01-01 00:00:00    object
# 2021-01-02 00:00:00       ...
#                         ...
# 2021-02-28 00:00:00       ...
# 2021-02-28 23:59:59       ...
# Name: date, dtype: object
# Dask Name: sort_index, 295 tasks

# %% [markdown]
# # Delayed computation

# %% [markdown]
# ## Exemplo 1

# %%
df['A'].max()
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
df['A'].max().compute()
# Out:
# 0.9999996676628308

# %% [markdown]
# ## Exemplo 2

# %%
df.groupby('Type').mean()
# Out:
# Dask DataFrame Structure:
#                      A        B        C        D        E
# npartitions=1
#                float64  float64  float64  float64  float64
#                    ...      ...      ...      ...      ...
# Dask Name: truediv, 374 tasks

# %%
df.groupby('Type').mean().compute()
# Out:
#                A         B         C         D         E
# Type
# Class1  0.500021  0.500159  0.499956  0.499640  0.499770
# Class2  0.499678  0.499987  0.499696  0.500180  0.499881
# Class3  0.500175  0.499797  0.499966  0.500100  0.499826
# Class4  0.500274  0.499719  0.500275  0.500228  0.500256
# Class5  0.499999  0.500522  0.500138  0.500192  0.500234

# %% [markdown]
# ## Exemplo 3

# %%
df['F'] = df['A'] + df['B']
df['F'] = df['F'] - df['F'].mean()
media = df['F'].mean()
media
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
media.compute()
# Out:
# -1.3143841877348196e-16

# %% [markdown]
# ## Exceções (métodos com compute implícito)

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995  Class3
# 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750  Class5
# 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110  Class2
# 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046  Class2
# 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855  Class3
#
#                             F
# date
# 2021-01-01 00:00:00  0.189947
# 2021-01-01 00:00:01  0.304757
# 2021-01-01 00:00:02  0.861750
# 2021-01-01 00:00:03 -0.487550
# 2021-01-01 00:00:04 -0.461997

# %%
df.tail()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-02-28 23:59:55  0.412063  0.018430  0.004757  0.023691  0.908250  Class5
# 2021-02-28 23:59:56  0.398651  0.804245  0.545502  0.643793  0.715667  Class5
# 2021-02-28 23:59:57  0.835641  0.489529  0.600274  0.920222  0.445715  Class2
# 2021-02-28 23:59:58  0.839915  0.888782  0.354771  0.341346  0.971440  Class4
# 2021-02-28 23:59:59  0.747639  0.139655  0.842183  0.567116  0.507573  Class2
#
#                             F
# date
# 2021-02-28 23:59:55 -0.569572
# 2021-02-28 23:59:56  0.202831
# 2021-02-28 23:59:57  0.325104
# 2021-02-28 23:59:58  0.728631
# 2021-02-28 23:59:59 -0.112771

# %%
#Cuidado
df.sample(frac=1e-5)
# Out:
# Dask DataFrame Structure:
#                            A        B        C        D        E    Type        F
# npartitions=59
# 2021-01-01 00:00:00  float64  float64  float64  float64  float64  object  float64
# 2021-01-02 00:00:00      ...      ...      ...      ...      ...     ...      ...
# ...                      ...      ...      ...      ...      ...     ...      ...
# 2021-02-28 00:00:00      ...      ...      ...      ...      ...     ...      ...
# 2021-02-28 23:59:59      ...      ...      ...      ...      ...     ...      ...
# Dask Name: sample, 829 tasks

# %%
df.sample(frac=1e-5).compute()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 16:05:44  0.216698  0.422936  0.136735  0.519777  0.281843  Class2
# 2021-01-02 05:02:10  0.702959  0.968581  0.467389  0.280760  0.588853  Class4
# 2021-01-29 07:51:29  0.215333
# 2021-01-30 12:32:06 -0.415623
# 2021-01-31 21:40:26 -0.054114
# 2021-02-01 03:17:05 -0.417920
# 2021-02-02 01:33:23  0.321296
# 2021-02-03 23:47:36 -0.399267
# 2021-02-04 20:32:39 -0.560581
# 2021-02-05 18:53:59 -0.014949
# 2021-02-06 17:27:40  0.503728
# 2021-02-07 12:34:36  0.377024
# 2021-02-08 16:24:10  0.067837
# 2021-02-09 17:41:15  0.153556
# 2021-02-10 13:53:39  0.464738
# 2021-02-11 11:05:26 -0.025274
# 2021-02-12 06:15:13 -0.236195
# 2021-02-13 06:32:00 -0.510743
# 2021-02-14 18:17:37 -0.022922
# 2021-02-15 03:16:38  0.062115
# 2021-02-16 13:47:58 -0.479717
# 2021-02-17 02:51:32 -0.341718
# 2021-02-18 11:56:50  0.678528
# 2021-02-19 17:37:24  0.159373
# 2021-02-20 03:17:03 -0.431288
# 2021-02-21 18:49:48  0.347681
# 2021-02-22 20:47:05 -0.117064
# 2021-02-23 18:04:22 -0.554938
# 2021-02-24 08:10:29 -0.961905
# 2021-02-25 03:02:05 -0.265906
# 2021-02-26 14:55:50 -0.209600
# 2021-02-27 06:23:10  0.271418
# 2021-02-28 09:51:54  0.548266

# %% [markdown]
# # Semelhanças com pandas
#
# A grande vantagem de Dask sobre, por exemplo, Spark

# %% [markdown]
# ## Filtrar linhas

# %%
df_1 = df[df.Type == 'Class1']

# %%
df_1.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:07  0.827363  0.478525  0.826150  0.728583  0.134825  Class1
# 2021-01-01 00:00:10  0.412788  0.630448  0.956777  0.235059  0.896744  Class1
# 2021-01-01 00:00:15  0.827425  0.857359  0.754480  0.996289  0.672775  Class1
# 2021-01-01 00:00:53  0.825701  0.899504  0.264561  0.261113  0.267173  Class1
# 2021-01-01 00:00:59  0.737701  0.734716  0.432248  0.316197  0.834699  Class1
#
#                             F
# date
# 2021-01-01 00:00:07  0.305822
# 2021-01-01 00:00:10  0.043170
# 2021-01-01 00:00:15  0.684719
# 2021-01-01 00:00:53  0.725139
# 2021-01-01 00:00:59  0.472350

# %% [markdown]
# ## Selecionar colunas

# %%
df_num = df[['A','B','C','D','E','F']]

# %%
df_num.head()
# Out:
#                             A         B         C         D         E  \
# date
# 2021-01-01 00:00:00  0.771390  0.418623  0.623215  0.401876  0.004995
# 2021-01-01 00:00:01  0.864748  0.440075  0.819741  0.478412  0.866750
# 2021-01-01 00:00:02  0.864099  0.997717  0.568261  0.435532  0.142110
# 2021-01-01 00:00:03  0.266226  0.246290  0.889184  0.231991  0.841046
# 2021-01-01 00:00:04  0.190853  0.347216  0.480630  0.422721  0.290855
#
#                             F
# date
# 2021-01-01 00:00:00  0.189947
# 2021-01-01 00:00:01  0.304757
# 2021-01-01 00:00:02  0.861750
# 2021-01-01 00:00:03 -0.487550
# 2021-01-01 00:00:04 -0.461997

# %% [markdown]
# ## Estatísticas simples

# %%
df.A.mean().compute()
# Out:
# 0.5000292140315263

# %% [markdown]
# ## Group by

# %%
df.groupby('Type').agg(['mean','std']).compute()
# Out:
#                A                   B                   C                   D  \
#             mean       std      mean       std      mean       std      mean
# Type
# Class1  0.500021  0.288660  0.500159  0.288619  0.499956  0.288754  0.499640
# Class2  0.499678  0.288692  0.499987  0.288781  0.499696  0.288975  0.500180
# Class3  0.500175  0.288799  0.499797  0.288944  0.499966  0.288800  0.500100
# Class4  0.500274  0.288835  0.499719  0.288691  0.500275  0.288721  0.500228
# Class5  0.499999  0.288547  0.500522  0.289014  0.500138  0.288558  0.500192
#
#                          E                   F
#              std      mean       std      mean       std
# Type
# Class1  0.288628  0.499770  0.288719  0.000114  0.408332
# Class2  0.288637  0.499881  0.288576 -0.000400  0.408214
# Class3  0.288863  0.499826  0.288844 -0.000095  0.408256
# Class4  0.288621  0.500256  0.288750 -0.000073  0.408137
# Class5  0.288662  0.500234  0.288657  0.000455  0.408246

# %% [markdown]
# # O dashboard do Dask
#
# (mostrar o dashboard)

# %% [markdown]
# # Resampling

# %%
x = df.index.head()
x
# Out:
# Index(['2021-01-01 00:00:00', '2021-01-01 00:00:01', '2021-01-01 00:00:02',
#        '2021-01-01 00:00:03', '2021-01-01 00:00:04'],
#       dtype='object', name='date')

# %%
df = dd.read_csv('dask_dataframes/2021-*-*.csv', )
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 dd.to_datetime(x, infer_datetime_format=True)
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\core.py:6940, in to_datetime(arg, meta, **kwargs)
#    6938     meta.name = arg.name
#    6939 elif not (is_dataframe_like(arg) or is_series_like(arg)):
# -> 6940     raise NotImplementedError(
#    6941         "dask.dataframe.to_datetime does not support "
#    6942         "non-index-able arguments (like scalars)"
#    6943     )
#    6944 else:
#    6945     meta = pd.Series([pd.Timestamp("2000", **tz_kwarg)])
#
# NotImplementedError: dask.dataframe.to_datetime does not support non-index-able arguments (like scalars)

# %%
df.index = df.index.astype('datetime')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df.index = df.index.astype('datetime')
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\core.py:2839, in _Frame.astype(self, dtype)
#    2837     meta = self._meta_nonempty.astype(dtype)
#    2838 else:
# -> 2839     meta = self._meta.astype(dtype)
#    2840 if hasattr(dtype, "items"):
#    2841     set_unknown = [
#    2842         k
#    2843         for k, v in dtype.items()
#    2844         if is_categorical_dtype(v) and getattr(v, "categories", None) is None
#    2845     ]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:902, in Index.astype(self, dtype, copy)
#     878 """
#     879 Create an Index with values cast to dtypes.
#     880
#    (...)
#     899     Index with values cast to specified dtype.
#     900 """
#     901 if dtype is not None:
# --> 902     dtype = pandas_dtype(dtype)
#     904 if is_dtype_equal(self.dtype, dtype):
#     905     return self.copy() if copy else self
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1776, in pandas_dtype(dtype)
#    1773 # try a numpy dtype
#    1774 # raise a consistent TypeError if failed
#    1775 try:
# -> 1776     npdtype = np.dtype(dtype)
#    1777 except SyntaxError as err:
#    1778     # np.dtype uses `eval` which can raise SyntaxError
#    1779     raise TypeError(f"data type '{dtype}' not understood") from err
#
# TypeError: data type 'datetime' not understood

# %%
df_diario = df.resample("1D")

# %%
df_media_diaria = df_diario.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df_media_diaria = df_diario.mean()
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\tseries\resample.py:214, in Resampler.mean(self)
#     212 @derived_from(pd_Resampler)
#     213 def mean(self):
# --> 214     return self._agg("mean")
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\tseries\resample.py:161, in Resampler._agg(self, how, meta, fill_value, how_args, how_kwargs)
#     156 name = "resample-" + tokenize(
#     157     self.obj, rule, kwargs, how, *how_args, **how_kwargs
#     158 )
#     160 # Create a grouper to determine closed and label conventions
# --> 161 newdivs, outdivs = _resample_bin_and_out_divs(
#     162     self.obj.divisions, rule, **kwargs
#     163 )
#     165 # Repartition divs into bins. These won't match labels after mapping
#     166 partitioned = self.obj.repartition(newdivs, force=True)
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\tseries\resample.py:69, in _resample_bin_and_out_divs(divisions, rule, closed, label)
#      67 # Determine bins to apply `how` to. Disregard labeling scheme.
#      68 divs = pd.Series(range(len(divisions)), index=divisions)
# ---> 69 temp = divs.resample(rule, closed=closed, label="left").count()
#      70 tempdivs = temp.loc[temp > 0].index
#      72 # Cleanup closed == 'right' and label == 'right'
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5306, in Series.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    5290 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5291 def resample(
#    5292     self,
#    (...)
#    5304     offset: TimedeltaConvertibleTypes | None = None,
#    5305 ) -> Resampler:
# -> 5306     return super().resample(
#    5307         rule=rule,
#    5308         axis=axis,
#    5309         closed=closed,
#    5310         label=label,
#    5311         convention=convention,
#    5312         kind=kind,
#    5313         loffset=loffset,
#    5314         base=base,
#    5315         on=on,
#    5316         level=level,
#    5317         origin=origin,
#    5318         offset=offset,
#    5319     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:8126, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8123 from pandas.core.resample import get_resampler
#    8125 axis = self._get_axis_number(axis)
# -> 8126 return get_resampler(
#    8127     self,
#    8128     freq=rule,
#    8129     label=label,
#    8130     closed=closed,
#    8131     axis=axis,
#    8132     kind=kind,
#    8133     loffset=loffset,
#    8134     convention=convention,
#    8135     base=base,
#    8136     key=on,
#    8137     level=level,
#    8138     origin=origin,
#    8139     offset=offset,
#    8140 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\resample.py:1382, in get_resampler(obj, kind, **kwds)
#    1378 """
#    1379 Create a TimeGrouper and return our resampler.
#    1380 """
#    1381 tg = TimeGrouper(**kwds)
# -> 1382 return tg._get_resampler(obj, kind=kind)
#
# File ~\anaconda3\lib\site-packages\pandas\core\resample.py:1558, in TimeGrouper._get_resampler(self, obj, kind)
#    1555 elif isinstance(ax, TimedeltaIndex):
#    1556     return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
# -> 1558 raise TypeError(
#    1559     "Only valid with DatetimeIndex, "
#    1560     "TimedeltaIndex or PeriodIndex, "
#    1561     f"but got an instance of '{type(ax).__name__}'"
#    1562 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
