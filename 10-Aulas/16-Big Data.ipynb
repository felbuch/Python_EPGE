# %% [markdown]
# # Cria base de dados para exemplo

# %% [markdown]
# * Uma observação para cada segundo entre 1-Jan-2021 até 28-Fev-2021.
# * Um arquivo CSV para cada dia do mês (31 para Janeiro + 28 para Fevereiro = 59 no total)
# * Colunas: _Timestamp_ + 5 colunas numéricas aleatórias + 1 coluna categórica

# %%
import pandas as pd
import numpy as np

dates = pd.date_range(start="1-1-2021", end="2-28-2021")

for dt in dates:
    ind_day = pd.date_range(start="%s 0:0:0"%dt.date(), end="%s 23:59:59"%dt.date(), freq="S")
    data = np.random.rand(len(ind_day), 5)

    cls = np.random.choice(["Class1", "Class2", "Class3", "Class4","Class5"], size=len(ind_day))

    df = pd.DataFrame(data=data, columns=["A", "B", "C", "D", "E"], index=ind_day)
    df["Type"] = cls

    df.to_csv("dask_dataframes/%s.csv"%dt.date())

# %%
import os
os.listdir("dask_dataframes/")
# Out:
# ['2021-01-01.csv',
#  '2021-01-02.csv',
#  '2021-01-03.csv',
#  '2021-01-04.csv',
#  '2021-01-05.csv',
#  '2021-01-06.csv',
#  '2021-01-07.csv',
#  '2021-01-08.csv',
#  '2021-01-09.csv',
#  '2021-01-10.csv',
#  '2021-01-11.csv',
#  '2021-01-12.csv',
#  '2021-01-13.csv',
#  '2021-01-14.csv',
#  '2021-01-15.csv',
#  '2021-01-16.csv',
#  '2021-01-17.csv',
#  '2021-01-18.csv',
#  '2021-01-19.csv',
#  '2021-01-20.csv',
#  '2021-01-21.csv',
#  '2021-01-22.csv',
#  '2021-01-23.csv',
#  '2021-01-24.csv',
#  '2021-01-25.csv',
#  '2021-01-26.csv',
#  '2021-01-27.csv',
#  '2021-01-28.csv',
#  '2021-01-29.csv',
#  '2021-01-30.csv',
#  '2021-01-31.csv',
#  '2021-02-01.csv',
#  '2021-02-02.csv',
#  '2021-02-03.csv',
#  '2021-02-04.csv',
#  '2021-02-05.csv',
#  '2021-02-06.csv',
#  '2021-02-07.csv',
#  '2021-02-08.csv',
#  '2021-02-09.csv',
#  '2021-02-10.csv',
#  '2021-02-11.csv',
#  '2021-02-12.csv',
#  '2021-02-13.csv',
#  '2021-02-14.csv',
#  '2021-02-15.csv',
#  '2021-02-16.csv',
#  '2021-02-17.csv',
#  '2021-02-18.csv',
#  '2021-02-19.csv',
#  '2021-02-20.csv',
#  '2021-02-21.csv',
#  '2021-02-22.csv',
#  '2021-02-23.csv',
#  '2021-02-24.csv',
#  '2021-02-25.csv',
#  '2021-02-26.csv',
#  '2021-02-27.csv',
#  '2021-02-28.csv']

# %% [markdown]
# # Cria cluster do dask

# %%
from dask.distributed import Client

client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GB")
client
# Out:
# <Client: 'tcp://127.0.0.1:57199' processes=2 threads=4, memory=1.86 GiB>

# %% [markdown]
# # Lê base de dados

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('dask_dataframes/2021-*-*.csv')

# %%
df.head()
# Out:
#             Unnamed: 0         A         B         C         D         E  \
# 0  2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866
# 1  2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779
# 2  2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251
# 3  2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214
# 4  2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885
#
#      Type
# 0  Class4
# 1  Class1
# 2  Class2
# 3  Class2
# 4  Class1

# %%
df.tail()
# Out:
#                 Unnamed: 0         A         B         C         D         E  \
# 86395  2021-02-28 23:59:55  0.467637  0.335700  0.556982  0.613883  0.022757
# 86396  2021-02-28 23:59:56  0.288385  0.547262  0.233291  0.904265  0.854336
# 86397  2021-02-28 23:59:57  0.387114  0.430303  0.223098  0.290961  0.154756
# 86398  2021-02-28 23:59:58  0.090263  0.858134  0.640929  0.271057  0.219644
# 86399  2021-02-28 23:59:59  0.745424  0.790635  0.937931  0.243355  0.491579
#
#          Type
# 86395  Class2
# 86396  Class4
# 86397  Class2
# 86398  Class1
# 86399  Class2

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# A             float64
# B             float64
# C             float64
# D             float64
# E             float64
# Type           object
# dtype: object

# %%
df = df.rename(columns={'Unnamed: 0':'date'}).set_index('date')

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1

# %%
df.tail()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-02-28 23:59:55  0.467637  0.335700  0.556982  0.613883  0.022757  Class2
# 2021-02-28 23:59:56  0.288385  0.547262  0.233291  0.904265  0.854336  Class4
# 2021-02-28 23:59:57  0.387114  0.430303  0.223098  0.290961  0.154756  Class2
# 2021-02-28 23:59:58  0.090263  0.858134  0.640929  0.271057  0.219644  Class1
# 2021-02-28 23:59:59  0.745424  0.790635  0.937931  0.243355  0.491579  Class2

# %%
df.dtypes
# Out:
# A       float64
# B       float64
# C       float64
# D       float64
# E       float64
# Type     object
# dtype: object

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'Type'], dtype='object')

# %%
#Não está como datetime!
df.index
# Out:
# Dask Index Structure:
# npartitions=59
# 2021-01-01 00:00:00    object
# 2021-01-02 00:00:00       ...
#                         ...
# 2021-02-28 00:00:00       ...
# 2021-02-28 23:59:59       ...
# Name: date, dtype: object
# Dask Name: sort_index, 295 tasks

# %%
df = dd.read_csv("dask_dataframes/2021-*-*.csv",
                 names=["date", "A", "B", "C", "D", "E", "Type"],
                 skiprows=1,
                 parse_dates=["date",]
                )

# %%
df.head()
# Out:
#                  date         A         B         C         D         E  \
# 0 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866
# 1 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779
# 2 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251
# 3 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214
# 4 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885
#
#      Type
# 0  Class4
# 1  Class1
# 2  Class2
# 3  Class2
# 4  Class1

# %%
df.dtypes
# Out:
# date    datetime64[ns]
# A              float64
# B              float64
# C              float64
# D              float64
# E              float64
# Type            object
# dtype: object

# %%
df = df.set_index('date')

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1

# %%
df.dtypes
# Out:
# A       float64
# B       float64
# C       float64
# D       float64
# E       float64
# Type     object
# dtype: object

# %% [markdown]
# # Delayed computation

# %% [markdown]
# ## Exemplo 1

# %%
df['A'].max()
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
df['A'].max().compute()
# Out:
# 0.9999999931358396

# %% [markdown]
# ## Exemplo 2

# %%
df.groupby('Type').mean()
# Out:
# Dask DataFrame Structure:
#                      A        B        C        D        E
# npartitions=1
#                float64  float64  float64  float64  float64
#                    ...      ...      ...      ...      ...
# Dask Name: truediv, 315 tasks

# %%
df.groupby('Type').mean().compute()
# Out:
#                A         B         C         D         E
# Type
# Class1  0.499745  0.499880  0.499960  0.499720  0.499834
# Class2  0.499628  0.499913  0.500430  0.500107  0.499778
# Class3  0.499710  0.499860  0.499722  0.499660  0.499885
# Class4  0.499992  0.499762  0.499931  0.500238  0.499909
# Class5  0.500198  0.500491  0.500110  0.500031  0.499649

# %% [markdown]
# ## Exemplo 3

# %%
df['F'] = df['A'] + df['B']
df['F'] = df['F'] - df['F'].mean()
media = df['F'].mean()
media
# Out:
# dd.Scalar<series-..., dtype=float64>

# %%
media.compute()
# Out:
# -3.396599455626593e-17

# %% [markdown]
# ## Exceções (métodos com compute implícito)

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-02-18 17:18:48 -0.412766
# 2021-02-19 00:36:16  0.341913
# 2021-02-20 02:56:33  0.205853
# 2021-02-21 09:44:45  0.505823
# 2021-02-22 08:15:45  0.411436
# 2021-02-23 14:57:01  0.013496
# 2021-02-24 18:13:08  0.559396
# 2021-02-25 22:58:34 -0.521794
# 2021-02-26 08:49:00 -0.526145
# 2021-02-27 20:00:06  0.058354
# 2021-02-28 02:54:49  0.007261

# %% [markdown]
# # Semelhanças com pandas
#
# A grande vantagem de Dask sobre, por exemplo, Spark

# %% [markdown]
# ## Filtrar linhas

# %%
df_1 = df[df.Type == 'Class1']

# %%
df_1.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1
# 2021-01-01 00:00:05  0.449564  0.076249  0.075330  0.508997  0.757593  Class1
# 2021-01-01 00:00:12  0.253887  0.376720  0.825048  0.950216  0.279805  Class1
# 2021-01-01 00:00:19  0.257207  0.671280  0.433995  0.955925  0.189143  Class1
#
#                             F
# date
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:04 -0.620377
# 2021-01-01 00:00:05 -0.474022
# 2021-01-01 00:00:12 -0.369229
# 2021-01-01 00:00:19 -0.071348

# %% [markdown]
# ## Selecionar colunas

# %%
df_num = df[['A','B','C','D','E','F']]

# %%
df_num.head()
# Out:
#                             A         B         C         D         E  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885
#
#                             F
# date
# 2021-01-01 00:00:00 -0.012974
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:02 -0.032076
# 2021-01-01 00:00:03 -0.163053
# 2021-01-01 00:00:04 -0.620377

# %% [markdown]
# ## Estatísticas simples

# %%
df.A.mean().compute()
# Out:
# 0.49985444309226584

# %% [markdown]
# ## Group by

# %%
df[['Type','A','B','C']].groupby('Type').agg(['mean','std']).compute()
# Out:
#                A                   B                   C
#             mean       std      mean       std      mean       std
# Type
# Class1  0.499745  0.288778  0.499880  0.288746  0.499960  0.288579
# Class2  0.499628  0.288792  0.499913  0.288743  0.500430  0.288445
# Class3  0.499710  0.288795  0.499860  0.288648  0.499722  0.288825
# Class4  0.499992  0.288698  0.499762  0.288727  0.499931  0.288570
# Class5  0.500198  0.288784  0.500491  0.288733  0.500110  0.288791

# %% [markdown]
# # Resampling

# %%
df_hora = df.resample("1H")

# %%
df_media_hora = df_hora.mean()
# Out:
# C:\Users\felbu\anaconda3\lib\site-packages\dask\dataframe\tseries\resample.py:190: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meta = getattr(meta_r, how)(*how_args, **how_kwargs)

# %%
df_media_hora
# Out:
# Dask DataFrame Structure:
#                            A        B        C        D        E        F
# npartitions=59
# 2021-01-01 00:00:00  float64  float64  float64  float64  float64  float64
# 2021-01-02 00:00:00      ...      ...      ...      ...      ...      ...
# ...                      ...      ...      ...      ...      ...      ...
# 2021-02-28 00:00:00      ...      ...      ...      ...      ...      ...
# 2021-02-28 23:00:00      ...      ...      ...      ...      ...      ...
# Dask Name: resample, 889 tasks

# %%
df_media_hora.head()
# Out:
#                             A         B         C         D         E  \
# date
# 2021-01-01 00:00:00  0.499349  0.494756  0.495592  0.495396  0.498922
# 2021-01-01 01:00:00  0.503274  0.509591  0.491930  0.496885  0.489440
# 2021-01-01 02:00:00  0.500421  0.503928  0.500714  0.505299  0.496326
# 2021-01-01 03:00:00  0.504126  0.502633  0.499923  0.496024  0.505823
# 2021-01-01 04:00:00  0.495030  0.501844  0.502325  0.496229  0.500867
#
#                             F
# date
# 2021-01-01 00:00:00 -0.005731
# 2021-01-01 01:00:00  0.013029
# 2021-01-01 02:00:00  0.004513
# 2021-01-01 03:00:00  0.006924
# 2021-01-01 04:00:00 -0.002962

# %% [markdown]
# # Partições

# %%
df.npartitions
# Out:
# 59

# %%
df.partitions[0]
# Out:
# Dask DataFrame Structure:
#                      A        B        C        D        E    Type        F
# npartitions=1
# 2021-01-01     float64  float64  float64  float64  float64  object  float64
# 2021-01-02         ...      ...      ...      ...      ...     ...      ...
# Dask Name: blocks, 712 tasks

# %%
df.partitions[0].head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1
#
#                             F
# date
# 2021-01-01 00:00:00 -0.012974
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:02 -0.032076
# 2021-01-01 00:00:03 -0.163053
# 2021-01-01 00:00:04 -0.620377

# %%
#df = df.set_index('date')

# %%
df_hora = df.repartition(freq="1H")

# %%
df_hora.npartitions
# Out:
# 1416

# %%
#Visualmente, não muda nada
df_hora.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1
#
#                             F
# date
# 2021-01-01 00:00:00 -0.012974
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:02 -0.032076
# 2021-01-01 00:00:03 -0.163053
# 2021-01-01 00:00:04 -0.620377

# %%
df_semana = df.repartition(freq='7D')
df_semana.npartitions
# Out:
# 9

# %%
#Aplicar uma função a cada partição
df_semana.map_partitions(lambda x: x.A.mean())
# Out:
# Dask Series Structure:
# npartitions=9
# 2021-01-01 00:00:00    float64
# 2021-01-07 00:00:00        ...
#                         ...
# 2021-02-25 00:00:00        ...
# 2021-02-28 23:59:59        ...
# dtype: float64
# Dask Name: lambda, 788 tasks

# %%
df_semana.map_partitions(lambda x: x.A.mean()).compute()
# Out:
# 0    0.499519
# 1    0.500534
# 2    0.500180
# 3    0.499919
# 4    0.500370
# 5    0.500467
# 6    0.499045
# 7    0.499012
# 8    0.499404
# dtype: float64

# %% [markdown]
# # O dashboard do Dask
#
# (mostrar o dashboard)

# %% [markdown]
# # Parquet
#
# * Por que Parquet?
# * Pyarrow e Fastparquet

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in c:\users\felbu\anaconda3\lib\site-packages (10.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\felbu\anaconda3\lib\site-packages (from pyarrow) (1.21.5)

# %% [markdown]
# ## Salvar

# %%
df.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1
#
#                             F
# date
# 2021-01-01 00:00:00 -0.012974
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:02 -0.032076
# 2021-01-01 00:00:03 -0.163053
# 2021-01-01 00:00:04 -0.620377

# %%
df.to_parquet('big_data.parq',engine='pyarrow')
# Out:
# [None]

# %% [markdown]
# ## Ler arquivo

# %%
df_2 = dd.read_parquet('big_data.parq', engine='pyarrow')

# %%
df_2.head()
# Out:
#                             A         B         C         D         E    Type  \
# date
# 2021-01-01 00:00:00  0.783249  0.203613  0.622932  0.365188  0.591866  Class4
# 2021-01-01 00:00:01  0.790864  0.794576  0.322750  0.706576  0.355779  Class1
# 2021-01-01 00:00:02  0.570402  0.397358  0.495860  0.776931  0.017251  Class2
# 2021-01-01 00:00:03  0.580558  0.256224  0.978140  0.211508  0.041214  Class2
# 2021-01-01 00:00:04  0.203923  0.175535  0.859204  0.468466  0.179885  Class1
#
#                             F
# date
# 2021-01-01 00:00:00 -0.012974
# 2021-01-01 00:00:01  0.585605
# 2021-01-01 00:00:02 -0.032076
# 2021-01-01 00:00:03 -0.163053
# 2021-01-01 00:00:04 -0.620377
