# %% [markdown]
# # Aplicação : Baixar dados do mercado secundário do site da ANBIMA
#
# Conteúdo:
#
# * Baixar arquivos de sites da internet usando o pacote `requests`
# * Manipular datas usando o pacote `datetime`
# * Configurar datas para o português usando o pacote `locale`
# * Programação defensiva usando o comando `assert`
# * Tratamento de uma base de dados difícil e real usando `pandas`
# * Concatenação de dataframes usando `pandas`

# %% [markdown]
# ## Parte 1: Baixar os dados

# %%
import requests
from datetime import date
import locale

#Faz com que nome dos meses seja retornado em Português (ex.: Fev, ao invés de. Feb)
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')
# Out:
# 'pt_BR.UTF-8'

# %%
data = date(2022,12,22)
hoje = date.today()

assert (hoje - data).days < 5, "ANBIMA só disponibiliza dados para os últimos 5 dias."

dia = data.day
mes = data.strftime("%b")
ano = data.strftime("%y")

download_link = f"https://www.anbima.com.br/informacoes/merc-sec/arqs/m{ano}{mes}{dia}.xls"
print(download_link)
# Out:
# https://www.anbima.com.br/informacoes/merc-sec/arqs/m22dez22.xls

# %%
r = requests.get(download_link)
print(r.status_code)
# Out:
# 200

# %%
with open('ANBIMA.xls','wb') as f:
    f.write(r.content)

# %% [markdown]
# ### Mesma coisa, em uma função

# %%
def baixar_dados_merc_sec(data):
    
    hoje = date.today()
    
    assert (hoje - data).days < 5, "ANBIMA só disponibiliza dados para os últimos 5 dias."
    
    dia = data.day
    mes = data.strftime("%b")
    ano = data.strftime("%y")
    
    download_link = f"https://www.anbima.com.br/informacoes/merc-sec/arqs/m{ano}{mes}{dia}.xls"
    r = requests.get(download_link)
    
    assert r.status_code == 200, "Falha ao realizar o download"
    
    nome_arquivo = f"ANBIMA_{ano}-{mes}-{dia}.xls"
    
    with open(nome_arquivo,'wb') as f:
        f.write(r.content)
    
    #Retornar o nome do arquivo será conveniente mais tarde
    return(nome_arquivo)

# %%
baixar_dados_merc_sec(date(2022,12,20))
# Out:
# 'ANBIMA_22-dez-20.xls'

# %% [markdown]
# ## Parte 2 : Arrumar os dados
#
# Vamos considerar a aba de NTN-B...

# %%
import pandas as pd

# %% [markdown]
# ### Dados brutos, sem tratamento

# %%
df = pd.read_excel("ANBIMA.xls", sheet_name="NTN-B")
df
# Out:
#                             Títulos Públicos Federais           Unnamed: 1  \
# 0                                                 NaN                  NaN
# 1                                          Papel IPCA                  NaN
# 2                                        Código SELIC    Data Base/Emissão
# 3                                                 NaN                  NaN
# 4                                              760100  2000-07-15 00:00:00
# 5                                              760199  2000-07-15 00:00:00
# 6                                              760199  2000-07-15 00:00:00
# 7                                              760199  2000-07-15 00:00:00
# 8                                              760199  2000-07-15 00:00:00
# 9                                              760199  2000-07-15 00:00:00
# 10                                             760199  2000-07-15 00:00:00
# 11                                             760199  2000-07-15 00:00:00
# 12                                             760199  2000-07-15 00:00:00
# 13                                             760199  2000-07-15 00:00:00
# 14                                             760199  2000-07-15 00:00:00
# 15                                             760199  2000-07-15 00:00:00
# 16                                             760199  2000-07-15 00:00:00
# 17                                             760199  2000-07-15 00:00:00
# 18                                             760199  2000-07-15 00:00:00
# 19  Quando uma taxa for interpolada será apresenta...                  NaN
# 20  Os preços unitários são calculados a partir da...                  NaN
# 21  para o mês, à exceção do período entre o dia d...                  NaN
# 22                 mês anterior, divulgado pelo IBGE.                  NaN
# 23                       Projeção IPCA para dezembro:                  NaN
# 24  Média apurada pela Comitê de Acompanhamento Ma...                  NaN
#
#                    Unnamed: 2  Unnamed: 3 Unnamed: 4       Unnamed: 5  \
# 0                         NaN         NaN        NaN              NaN
# 1   NTN-B - Taxa (% a.a.)/252         NaN        NaN              NaN
# 2          Data de Vencimento  Tx. Compra  Tx. Venda  Tx. Indicativas
# 3                         NaN         NaN        NaN              NaN
# 4         2023-03-15 00:00:00       6.294     6.2383           6.2715
# 5         2023-05-15 00:00:00      6.2948     6.2467           6.2666
# 6         2024-08-15 00:00:00      6.8127     6.7843           6.7954
# 7         2025-05-15 00:00:00      6.4398     6.4121           6.4256
# 8         2026-08-15 00:00:00      6.4245     6.4102           6.4194
# 9         2027-05-15 00:00:00       6.341     6.3155           6.3292
# 10        2028-08-15 00:00:00      6.3569     6.3282           6.3441
# 11        2030-08-15 00:00:00      6.2776     6.2526           6.2669
# 12        2032-08-15 00:00:00      6.3037      6.261           6.2812
# 13        2035-05-15 00:00:00      6.3067     6.2711           6.2858
# 14        2040-08-15 00:00:00      6.3692     6.3222           6.3448
# 15        2045-05-15 00:00:00      6.3962      6.366           6.3825
# 16        2050-08-15 00:00:00      6.4129      6.383            6.397
# 17        2055-05-15 00:00:00      6.3941     6.3639           6.3772
# 18        2060-08-15 00:00:00      6.3925     6.3551            6.372
# 19                        NaN         NaN        NaN              NaN
# 20                        NaN         NaN        NaN              NaN
# 21                        NaN         NaN        NaN              NaN
# 22                        NaN         NaN        NaN              NaN
# 23                        NaN         NaN        NaN              NaN
# 24                        NaN         NaN        NaN              NaN
#
#      Unnamed: 6            Unnamed: 7   Unnamed: 8    Unnamed: 9   22/Dez/2022
# 0           NaN                   NaN          NaN           NaN           NaN
# 1           NaN                   NaN          NaN           NaN           NaN
# 2            PU  Intervalo Indicativo          NaN           NaN           NaN
# 3           NaN           Mínimo (D0)  Máximo (D0)  Mínimo (D+1)  Máximo (D+1)
# 4    4051.75308                5.2727       8.1216        5.3047        8.1747
# 5   4012.895122                5.5054       7.6163        5.5317        7.6582
# 6   4027.586056                6.5164       7.2447        6.5238        7.2524
# 7   3981.546218                6.1752       6.8467        6.1531        6.8249
# 8   4021.621106                6.1379       6.7326         6.132        6.7268
# 9   3969.037778                 6.052       6.6301        6.0239        6.6022
# 10  4013.437753                6.0763       6.6211        6.0355        6.5805
# 11  4016.338434                6.0283        6.516        5.9868        6.4746
# 12  3999.173742                6.0784       6.5291        6.0241        6.4748
# 13  3927.003833                6.1089       6.5274        6.0507        6.4692
# 14  3938.905804                6.1828       6.5676        6.1339        6.5185
# 15  3847.085474                6.2277       6.5966        6.1831        6.5518
# 16  3882.547999                6.2517         6.61        6.2052        6.5633
# 17  3823.919923                6.2371       6.5892        6.1899        6.5418
# 18  3876.223955                6.2316       6.5791         6.188        6.5353
# 19          NaN                   NaN          NaN           NaN           NaN
# 20          NaN                   NaN          NaN           NaN           NaN
# 21          NaN                   NaN          NaN           NaN           NaN
# 22          NaN                   NaN          NaN           NaN           NaN
# 23          NaN                   NaN          NaN           NaN           NaN
# 24          NaN                   NaN          NaN           NaN           NaN

# %% [markdown]
# __Questões a serem tratadas__
# * Cabeçalho da tabela está na linha 2
# * Últimas 4 colunas do cabeçalho estão na linha 3
# * Dados começam na linha 4
# * Últimas 6 linhas não contêm dados

# %% [markdown]
# ### Dados tratados

# %%
df = pd.read_excel("ANBIMA.xls", sheet_name="NTN-B", skiprows=3)
df.columns.values[-4:] = df.iloc[0,-4:]
df = df.iloc[1:-6,:]
df
# Out:
#    Código SELIC Data Base/Emissão Data de Vencimento  Tx. Compra  Tx. Venda  \
# 1        760100        2000-07-15         2023-03-15      6.2940     6.2383
# 2        760199        2000-07-15         2023-05-15      6.2948     6.2467
# 3        760199        2000-07-15         2024-08-15      6.8127     6.7843
# 4        760199        2000-07-15         2025-05-15      6.4398     6.4121
# 5        760199        2000-07-15         2026-08-15      6.4245     6.4102
# 6        760199        2000-07-15         2027-05-15      6.3410     6.3155
# 7        760199        2000-07-15         2028-08-15      6.3569     6.3282
# 8        760199        2000-07-15         2030-08-15      6.2776     6.2526
# 9        760199        2000-07-15         2032-08-15      6.3037     6.2610
# 10       760199        2000-07-15         2035-05-15      6.3067     6.2711
# 11       760199        2000-07-15         2040-08-15      6.3692     6.3222
# 12       760199        2000-07-15         2045-05-15      6.3962     6.3660
# 13       760199        2000-07-15         2050-08-15      6.4129     6.3830
# 14       760199        2000-07-15         2055-05-15      6.3941     6.3639
# 15       760199        2000-07-15         2060-08-15      6.3925     6.3551
#
#     Tx. Indicativas           PU Mínimo (D0) Máximo (D0) Mínimo (D+1)  \
# 1            6.2715  4051.753080      5.2727      8.1216       5.3047
# 2            6.2666  4012.895122      5.5054      7.6163       5.5317
# 3            6.7954  4027.586056      6.5164      7.2447       6.5238
# 4            6.4256  3981.546218      6.1752      6.8467       6.1531
# 5            6.4194  4021.621106      6.1379      6.7326        6.132
# 6            6.3292  3969.037778       6.052      6.6301       6.0239
# 7            6.3441  4013.437753      6.0763      6.6211       6.0355
# 8            6.2669  4016.338434      6.0283       6.516       5.9868
# 9            6.2812  3999.173742      6.0784      6.5291       6.0241
# 10           6.2858  3927.003833      6.1089      6.5274       6.0507
# 11           6.3448  3938.905804      6.1828      6.5676       6.1339
# 12           6.3825  3847.085474      6.2277      6.5966       6.1831
# 13           6.3970  3882.547999      6.2517        6.61       6.2052
# 14           6.3772  3823.919923      6.2371      6.5892       6.1899
# 15           6.3720  3876.223955      6.2316      6.5791        6.188
#
#    Máximo (D+1)
# 1        8.1747
# 2        7.6582
# 3        7.2524
# 4        6.8249
# 5        6.7268
# 6        6.6022
# 7        6.5805
# 8        6.4746
# 9        6.4748
# 10       6.4692
# 11       6.5185
# 12       6.5518
# 13       6.5633
# 14       6.5418
# 15       6.5353

# %% [markdown]
# ### Mesma coisa, em uma função

# %%
def arruma_base_merc_sec(path_arquivo):
    df = pd.read_excel(path_arquivo, sheet_name="NTN-B", skiprows=3)
    df.columns.values[-4:] = df.iloc[0,-4:]
    df = df.iloc[1:-6,:]
    return(df)

# %%
df = arruma_base_merc_sec("ANBIMA.xls")

#Salvar para usar depois
df.to_excel("ANBIMA.xlsx", index=False)

# %% [markdown]
# ## Parte 3: Concatena dados de hoje a arquivo pré-existente
#
# Vamos supor que o arquivo pré-existente seja o ANBIMA.xlsx

# %%
dados_historicos = pd.read_excel("ANBIMA.xlsx")
dados_historicos.head()
# Out:
#    Código SELIC Data Base/Emissão Data de Vencimento  Tx. Compra  Tx. Venda  \
# 0        760100        2000-07-15         2023-03-15      6.2940     6.2383
# 1        760199        2000-07-15         2023-05-15      6.2948     6.2467
# 2        760199        2000-07-15         2024-08-15      6.8127     6.7843
# 3        760199        2000-07-15         2025-05-15      6.4398     6.4121
# 4        760199        2000-07-15         2026-08-15      6.4245     6.4102
#
#    Tx. Indicativas           PU  Mínimo (D0)  Máximo (D0)  Mínimo (D+1)  \
# 0           6.2715  4051.753080       5.2727       8.1216        5.3047
# 1           6.2666  4012.895122       5.5054       7.6163        5.5317
# 2           6.7954  4027.586056       6.5164       7.2447        6.5238
# 3           6.4256  3981.546218       6.1752       6.8467        6.1531
# 4           6.4194  4021.621106       6.1379       6.7326        6.1320
#
#    Máximo (D+1)
# 0        8.1747
# 1        7.6582
# 2        7.2524
# 3        6.8249
# 4        6.7268

# %%
dados_historicos.shape
# Out:
# (15, 11)

# %%
#path_dados_de_hoje = baixar_dados_merc_sec(date.today())
path_dados_de_hoje = baixar_dados_merc_sec(date(2022,12,23))
dados_de_hoje = arruma_base_merc_sec(path_dados_de_hoje)
dados_de_hoje.head()
# Out:
#   Código SELIC Data Base/Emissão Data de Vencimento  Tx. Compra  Tx. Venda  \
# 1       760100        2000-07-15         2023-03-15      6.6300     6.5780
# 2       760199        2000-07-15         2023-05-15      6.6321     6.5868
# 3       760199        2000-07-15         2024-08-15      6.7561     6.7283
# 4       760199        2000-07-15         2025-05-15      6.3338     6.3050
# 5       760199        2000-07-15         2026-08-15      6.3300     6.3041
#
#    Tx. Indicativas           PU Mínimo (D0) Máximo (D0) Mínimo (D+1)  \
# 1           6.6000  4050.963460      5.3047      8.1747       5.6299
# 2           6.6043  4010.012549      5.5317      7.6582       5.8678
# 3           6.7437  4032.669047      6.5238      7.2524        6.472
# 4           6.3194  3992.432511      6.1531      6.8249        6.047
# 5           6.3183  4036.093263       6.132      6.7268       6.0309
#
#   Máximo (D+1)
# 1       8.5214
# 2       8.0098
# 3        7.201
# 4       6.7191
# 5       6.6259

# %%
dados_de_hoje.shape
# Out:
# (15, 11)

# %%
dados_historicos = pd.concat([dados_historicos, dados_de_hoje], axis=0)
dados_historicos.head()
# Out:
#   Código SELIC Data Base/Emissão Data de Vencimento  Tx. Compra  Tx. Venda  \
# 0       760100        2000-07-15         2023-03-15      6.2940     6.2383
# 1       760199        2000-07-15         2023-05-15      6.2948     6.2467
# 2       760199        2000-07-15         2024-08-15      6.8127     6.7843
# 3       760199        2000-07-15         2025-05-15      6.4398     6.4121
# 4       760199        2000-07-15         2026-08-15      6.4245     6.4102
#
#    Tx. Indicativas           PU Mínimo (D0) Máximo (D0) Mínimo (D+1)  \
# 0           6.2715  4051.753080      5.2727      8.1216       5.3047
# 1           6.2666  4012.895122      5.5054      7.6163       5.5317
# 2           6.7954  4027.586056      6.5164      7.2447       6.5238
# 3           6.4256  3981.546218      6.1752      6.8467       6.1531
# 4           6.4194  4021.621106      6.1379      6.7326        6.132
#
#   Máximo (D+1)
# 0       8.1747
# 1       7.6582
# 2       7.2524
# 3       6.8249
# 4       6.7268

# %%
from datetime import timedelta

# %%
dados_historicos.shape
# Out:
# (30, 11)

# %% [markdown]
# ### Mesma coisa, em uma função

# %%
def atualiza_arquivo_historico(path_arquivo_historico):
    
    #Carrega dados históricos
    dados_historicos = pd.read_excel(path_arquivo_historico)
    
    #Carrega dados de hoje
    path_dados_de_hoje = baixar_dados_merc_sec(date.today())
    dados_de_hoje = arruma_base_merc_sec(path_dados_de_hoje)
    
    #Concatena dados de hoje aos dados históricos
    dados_historicos = pd.concat([dados_historicos, dados_de_hoje], axis=0)
    
    return(dados_historicos)

# %%
atualiza_arquivo_historico("ANBIMA.xlsx")
# Out:
#    Código SELIC Data Base/Emissão Data de Vencimento  Tx. Compra  Tx. Venda  \
# 0        760100        2000-07-15         2023-03-15      6.2940     6.2383
# 1        760199        2000-07-15         2023-05-15      6.2948     6.2467
# 2        760199        2000-07-15         2024-08-15      6.8127     6.7843
# 3        760199        2000-07-15         2025-05-15      6.4398     6.4121
# 4        760199        2000-07-15         2026-08-15      6.4245     6.4102
# 5        760199        2000-07-15         2027-05-15      6.3410     6.3155
# 6        760199        2000-07-15         2028-08-15      6.3569     6.3282
# 7        760199        2000-07-15         2030-08-15      6.2776     6.2526
# 8        760199        2000-07-15         2032-08-15      6.3037     6.2610
# 9        760199        2000-07-15         2035-05-15      6.3067     6.2711
# 10       760199        2000-07-15         2040-08-15      6.3692     6.3222
# 11       760199        2000-07-15         2045-05-15      6.3962     6.3660
# 12       760199        2000-07-15         2050-08-15      6.4129     6.3830
# 13       760199        2000-07-15         2055-05-15      6.3941     6.3639
# 14       760199        2000-07-15         2060-08-15      6.3925     6.3551
# 1        760100        2000-07-15         2023-03-15      6.6300     6.5780
# 2        760199        2000-07-15         2023-05-15      6.6321     6.5868
# 3        760199        2000-07-15         2024-08-15      6.7561     6.7283
# 4        760199        2000-07-15         2025-05-15      6.3338     6.3050
# 5        760199        2000-07-15         2026-08-15      6.3300     6.3041
# 6        760199        2000-07-15         2027-05-15      6.2635     6.2286
# 7        760199        2000-07-15         2028-08-15      6.2694     6.2357
# 8        760199        2000-07-15         2030-08-15      6.2089     6.1731
# 9        760199        2000-07-15         2032-08-15      6.2218     6.1894
# 10       760199        2000-07-15         2035-05-15      6.2352     6.1993
# 11       760199        2000-07-15         2040-08-15      6.3016     6.2597
# 12       760199        2000-07-15         2045-05-15      6.3328     6.2958
# 13       760199        2000-07-15         2050-08-15      6.3410     6.2961
# 14       760199        2000-07-15         2055-05-15      6.3257     6.2761
# 15       760199        2000-07-15         2060-08-15      6.3200     6.2694
#
#     Tx. Indicativas           PU Mínimo (D0) Máximo (D0) Mínimo (D+1)  \
# 0            6.2715  4051.753080      5.2727      8.1216       5.3047
# 1            6.2666  4012.895122      5.5054      7.6163       5.5317
# 2            6.7954  4027.586056      6.5164      7.2447       6.5238
# 3            6.4256  3981.546218      6.1752      6.8467       6.1531
# 4            6.4194  4021.621106      6.1379      6.7326        6.132
# 5            6.3292  3969.037778       6.052      6.6301       6.0239
# 6            6.3441  4013.437753      6.0763      6.6211       6.0355
# 7            6.2669  4016.338434      6.0283       6.516       5.9868
# 8            6.2812  3999.173742      6.0784      6.5291       6.0241
# 9            6.2858  3927.003833      6.1089      6.5274       6.0507
# 10           6.3448  3938.905804      6.1828      6.5676       6.1339
# 11           6.3825  3847.085474      6.2277      6.5966       6.1831
# 12           6.3970  3882.547999      6.2517        6.61       6.2052
# 13           6.3772  3823.919923      6.2371      6.5892       6.1899
# 14           6.3720  3876.223955      6.2316      6.5791        6.188
# 1            6.6000  4050.963460      5.3047      8.1747       5.6299
# 2            6.6043  4010.012549      5.5317      7.6582       5.8678
# 3            6.7437  4032.669047      6.5238      7.2524        6.472
# 4            6.3194  3992.432511      6.1531      6.8249        6.047
# 5            6.3183  4036.093263       6.132      6.7268       6.0309
# 6            6.2478  3982.850293      6.0239      6.6022       5.9425
# 7            6.2571  4031.092630      6.0355      6.5805       5.9484
# 8            6.1898  4036.129181      5.9868      6.4746       5.9096
# 9            6.2055  4021.977351      6.0241      6.4748       5.9484
# 10           6.2145  3952.279785      6.0507      6.4692       5.9795
# 11           6.2823  3965.976650      6.1339      6.5185       6.0714
# 12           6.3144  3879.612970      6.1831      6.5518       6.1151
# 13           6.3187  3922.730955      6.2052      6.5633       6.1272
# 14           6.3010  3865.173792      6.1899      6.5418        6.114
# 15           6.2947  3919.749732       6.188      6.5353       6.1111
#
#    Máximo (D+1)
# 0        8.1747
# 1        7.6582
# 2        7.2524
# 3        6.8249
# 4        6.7268
# 5        6.6022
# 6        6.5805
# 7        6.4746
# 8        6.4748
# 9        6.4692
# 10       6.5185
# 11       6.5518
# 12       6.5633
# 13       6.5418
# 14       6.5353
# 1        8.5214
# 2        8.0098
# 3         7.201
# 4        6.7191
# 5        6.6259
# 6        6.5209
# 7        6.4936
# 8        6.3975
# 9        6.3991
# 10       6.3978
# 11       6.4559
# 12       6.4836
# 13       6.4848
# 14       6.4654
# 15       6.4578

# %%
hoje = date.today()
hoje - timedelta(days=0)
# Out:
# datetime.date(2022, 12, 24)

# %%
dados_consolidados = pd.DataFrame([])
dias_corridos_atras = 0
dias_uteis_atras = 0

while dias_uteis_atras <= 5:
    try:
        data = hoje - timedelta(days = dias_corridos_atras)
        print(data)
        dia, mes, ano = data.days, data.month, data.year
        dados_do_dia = baixar_dados_merc_sec(dia, mes, ano)
        #dados_do_dia = arruma_base_merc_sec(dados_do_dia)
        #dados_consolidados = pd.concat([dados_consolidados, dados_do_dia], axis=1)
        dias_uteis_atras += 1
    except:
        pass
    
    dias_corridos_atras += 1

    
dados_consolidados.shape
